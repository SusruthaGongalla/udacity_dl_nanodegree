# %% [markdown]
# # Face Generation
# In this project, you'll use generative adversarial networks to generate new images of faces.
# ### Get the Data
# You'll be using two datasets in this project:
# - MNIST
# - CelebA
#
# Since the celebA dataset is complex and you're doing GANs in a project for the first time, we want you to test your neural network on MNIST before CelebA.  Running the GANs on MNIST will allow you to see how well your model trains sooner.
#
# If you're using [FloydHub](https://www.floydhub.com/), set `data_dir` to "/input" and use the [FloydHub data ID](http://docs.floydhub.com/home/using_datasets/) "R5KrjnANiKVhLWAkpXhNBe".

# %%
data_dir = './data'

# FloydHub - Use with data ID "R5KrjnANiKVhLWAkpXhNBe"
#data_dir = '/input'


"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import helper

helper.download_extract('mnist', data_dir)
helper.download_extract('celeba', data_dir)
# Out:
# Found mnist Data
# Found celeba Data

# %% [markdown]
# ## Explore the Data
# ### MNIST
# As you're aware, the [MNIST](http://yann.lecun.com/exdb/mnist/) dataset contains images of handwritten digits. You can view the first number of examples by changing `show_n_images`.

# %%
show_n_images = 25

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
import os
from glob import glob
from matplotlib import pyplot

mnist_images = helper.get_batch(glob(os.path.join(data_dir, 'mnist/*.jpg'))[:show_n_images], 28, 28, 'L')
pyplot.imshow(helper.images_square_grid(mnist_images, 'L'), cmap='gray')

# %% [markdown]
# ### CelebA
# The [CelebFaces Attributes Dataset (CelebA)](http://mmlab.ie.cuhk.edu.hk/projects/CelebA.html) dataset contains over 200,000 celebrity images with annotations.  Since you're going to be generating faces, you won't need the annotations.  You can view the first number of examples by changing `show_n_images`.

# %%
show_n_images = 25

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
mnist_images = helper.get_batch(glob(os.path.join(data_dir, 'img_align_celeba/*.jpg'))[:show_n_images], 28, 28, 'RGB')
pyplot.imshow(helper.images_square_grid(mnist_images, 'RGB'))

# %% [markdown]
# ## Preprocess the Data
# Since the project's main focus is on building the GANs, we'll preprocess the data for you.  The values of the MNIST and CelebA dataset will be in the range of -0.5 to 0.5 of 28x28 dimensional images.  The CelebA images will be cropped to remove parts of the image that don't include a face, then resized down to 28x28.
#
# The MNIST images are black and white images with a single [color channel](https://en.wikipedia.org/wiki/Channel_(digital_image%29) while the CelebA images have [3 color channels (RGB color channel)](https://en.wikipedia.org/wiki/Channel_(digital_image%29#RGB_Images).
# ## Build the Neural Network
# You'll build the components necessary to build a GANs by implementing the following functions below:
# - `model_inputs`
# - `discriminator`
# - `generator`
# - `model_loss`
# - `model_opt`
# - `train`
#
# ### Check the Version of TensorFlow and Access to GPU
# This will check to make sure you have the correct version of TensorFlow and access to a GPU

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
from distutils.version import LooseVersion
import warnings
import tensorflow as tf

# Check TensorFlow Version
assert LooseVersion(tf.__version__) >= LooseVersion('1.0'), 'Please use TensorFlow version 1.0 or newer.  You are using {}'.format(tf.__version__)
print('TensorFlow Version: {}'.format(tf.__version__))

# Check for a GPU
if not tf.test.gpu_device_name():
    warnings.warn('No GPU found. Please use a GPU to train your neural network.')
else:
    print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
# Out:
# TensorFlow Version: 1.10.1
# Default GPU Device: /device:GPU:0

# %% [markdown]
# ### Input
# Implement the `model_inputs` function to create TF Placeholders for the Neural Network. It should create the following placeholders:
# - Real input images placeholder with rank 4 using `image_width`, `image_height`, and `image_channels`.
# - Z input placeholder with rank 2 using `z_dim`.
# - Learning rate placeholder with rank 0.
#
# Return the placeholders in the following the tuple (tensor of real input images, tensor of z data)

# %%
import problem_unittests as tests

def model_inputs(image_width, image_height, image_channels, z_dim):
    """
    Create the model inputs
    :param image_width: The input image width
    :param image_height: The input image height
    :param image_channels: The number of image channels
    :param z_dim: The dimension of Z
    :return: Tuple of (tensor of real input images, tensor of z data, learning rate)
    """
    # TODO: Implement Function
    input_images = tf.placeholder(dtype=tf.float32, shape=[None, image_width, image_height, image_channels])
    z_data = tf.placeholder(dtype=tf.float32, shape=[None, z_dim])
    learning_rate = tf.placeholder(dtype=tf.float32)

    return (input_images, z_data, learning_rate)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_inputs(model_inputs)
# Out:
# Tests Passed

# %% [markdown]
# ### Discriminator
# Implement `discriminator` to create a discriminator neural network that discriminates on `images`.  This function should be able to reuse the variables in the neural network.  Use [`tf.variable_scope`](https://www.tensorflow.org/api_docs/python/tf/variable_scope) with a scope name of "discriminator" to allow the variables to be reused.  The function should return a tuple of (tensor output of the discriminator, tensor logits of the discriminator).

# %%
def discriminator(images, reuse=False):
    """
    Create the discriminator network
    :param images: Tensor of input image(s)
    :param reuse: Boolean if the weights should be reused
    :return: Tuple of (tensor output of the discriminator, tensor logits of the discriminator)
    """
    # TODO: Implement Function
    alpha = 0.2
    drop_rate = 0.2
    
    with tf.variable_scope("discriminator", reuse=reuse):
        # input shape: 28x28x3
        layer1 = tf.layers.conv2d(images, 64, 5, strides=2, padding='same')
        layer1 = tf.maximum(alpha * layer1, layer1)
#         layer1 = tf.layers.dropout(layer1, rate=drop_rate)
#         print(layer1.get_shape())
        
        # input shape: 14x14x64
        layer2 = tf.layers.conv2d(layer1, 128, 5, strides=2, padding='same')
        layer2 = tf.layers.batch_normalization(layer2, training=True)
        layer2 = tf.maximum(alpha * layer2, layer2)
        layer2 = tf.layers.dropout(layer2, rate=drop_rate)
#         print(layer2.get_shape())
        
        # input shape: 7x7x128
        layer3 = tf.layers.conv2d(layer2, 256, 5, strides=1, padding='same')
        layer3 = tf.layers.batch_normalization(layer3, training=True)
        layer3 = tf.maximum(alpha * layer3, layer3)
        layer3 = tf.layers.dropout(layer3, rate=drop_rate)
#         print(layer3.get_shape())
        
        # input shape: 7x7x256
        flat_out = tf.reshape(layer3, (-1, 
                                       layer3.shape[1]*layer3.shape[2]*layer3.shape[3]))
#         print(flat_out.get_shape())
        
        # input shape: 1x4096
        logits = tf.layers.dense(flat_out, 1)
#         print(logits.get_shape())
        
        output = tf.sigmoid(logits)
    return (output, logits)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_discriminator(discriminator, tf)
# Out:
# Tests Passed

# %% [markdown]
# ### Generator
# Implement `generator` to generate an image using `z`. This function should be able to reuse the variables in the neural network.  Use [`tf.variable_scope`](https://www.tensorflow.org/api_docs/python/tf/variable_scope) with a scope name of "generator" to allow the variables to be reused. The function should return the generated 28 x 28 x `out_channel_dim` images.

# %%
def generator(z, out_channel_dim, is_train=True):
    """
    Create the generator network
    :param z: Input z
    :param out_channel_dim: The number of channels in the output image
    :param is_train: Boolean if generator is being used for training
    :return: The tensor output of the generator
    """
    # TODO: Implement Function
    alpha = 0.1
    reuse = False
    if is_train == False:
        reuse = True
    with tf.variable_scope("generator", reuse=reuse):

        layer1 = tf.layers.dense(z, 512*7*7)
        layer1 = tf.reshape(layer1, (-1, 7, 7, 512))
        layer1 = tf.maximum(layer1 * alpha, layer1)
#         print(layer1.get_shape())
        
        # Input shape: 7x7x512
        layer2 = tf.layers.conv2d_transpose(layer1, 256, 3, strides=2, padding='same')
        layer2 = tf.layers.batch_normalization(layer2, training=is_train)
        layer2 = tf.maximum(layer2 * alpha, layer2)
#         print(layer2.get_shape())
        
        # Input shape: 14x14x256
        layer3 = tf.layers.conv2d_transpose(layer2, 128, 3, strides=2, padding='same')
        layer3 = tf.layers.batch_normalization(layer3, training=is_train)
        layer3 = tf.maximum(layer3 * alpha, layer3)
#         print(layer3.get_shape())
        
        # Input shape: 28x28x128
        logits = tf.layers.conv2d_transpose(layer3, out_channel_dim, 3, strides=1, padding='same')
#         print(logits.get_shape())

        # Input shape: 28x28xout_channel_dim
        output = tf.tanh(logits)
    
    return output


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_generator(generator, tf)
# Out:
# Tests Passed

# %% [markdown]
# ### Loss
# Implement `model_loss` to build the GANs for training and calculate the loss.  The function should return a tuple of (discriminator loss, generator loss).  Use the following functions you implemented:
# - `discriminator(images, reuse=False)`
# - `generator(z, out_channel_dim, is_train=True)`

# %%
def model_loss(input_real, input_z, out_channel_dim):
    """
    Get the loss for the discriminator and generator
    :param input_real: Images from the real dataset
    :param input_z: Z input
    :param out_channel_dim: The number of channels in the output image
    :return: A tuple of (discriminator loss, generator loss)
    """
    # TODO: Implement Function
    smooth = 0.1
    
    gen_output = generator(input_z, out_channel_dim, is_train=True)
    
    real_output, real_logits = discriminator(input_real, reuse=False)
    fake_output, fake_logits = discriminator(gen_output, reuse=True)
    
    disc_loss_real = tf.reduce_mean(
        tf.nn.sigmoid_cross_entropy_with_logits(logits=real_logits,
                                                labels=tf.ones_like(real_logits)*(1-smooth)))
    disc_loss_fake = tf.reduce_mean(
        tf.nn.sigmoid_cross_entropy_with_logits(logits=fake_logits,
                                                labels=(tf.zeros_like(fake_logits))))
    d_loss = disc_loss_real + disc_loss_fake
    
    g_loss = tf.reduce_mean(
             tf.nn.sigmoid_cross_entropy_with_logits(logits=fake_logits,
                                                     labels=tf.ones_like(fake_logits)))
    
    return (d_loss, g_loss)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_loss(model_loss)
# Out:
# Tests Passed

# %% [markdown]
# ### Optimization
# Implement `model_opt` to create the optimization operations for the GANs. Use [`tf.trainable_variables`](https://www.tensorflow.org/api_docs/python/tf/trainable_variables) to get all the trainable variables.  Filter the variables with names that are in the discriminator and generator scope names.  The function should return a tuple of (discriminator training operation, generator training operation).

# %%
def model_opt(d_loss, g_loss, learning_rate, beta1):
    """
    Get optimization operations
    :param d_loss: Discriminator loss Tensor
    :param g_loss: Generator loss Tensor
    :param learning_rate: Learning Rate Placeholder
    :param beta1: The exponential decay rate for the 1st moment in the optimizer
    :return: A tuple of (discriminator training operation, generator training operation)
    """
    # TODO: Implement Function
    all_variables = tf.trainable_variables()
    gen_vars = [variable for variable in all_variables if variable.name.startswith('generator')]
    disc_vars = [variable for variable in all_variables if variable.name.startswith('discriminator')]

    # Minimize both players' costs simultaneously
    disc_train_opt = tf.train.AdamOptimizer(learning_rate, beta1=beta1).minimize(d_loss, var_list=disc_vars)
    
    update_ops = tf.get_collection(tf.GraphKeys.UPDATE_OPS)
    gen_ops = [op for op in update_ops if op.name.startswith('generator')]
    with tf.control_dependencies(gen_ops):
        gen_train_opt = tf.train.AdamOptimizer(learning_rate, beta1=beta1).minimize(g_loss, var_list=gen_vars)
    
    return (disc_train_opt, gen_train_opt)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_opt(model_opt, tf)
# Out:
# Tests Passed

# %% [markdown]
# ## Neural Network Training
# ### Show Output
# Use this function to show the current output of the generator during training. It will help you determine how well the GANs is training.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np

def show_generator_output(sess, n_images, input_z, out_channel_dim, image_mode):
    """
    Show example output for the generator
    :param sess: TensorFlow session
    :param n_images: Number of Images to display
    :param input_z: Input Z Tensor
    :param out_channel_dim: The number of channels in the output image
    :param image_mode: The mode to use for images ("RGB" or "L")
    """
    cmap = None if image_mode == 'RGB' else 'gray'
    z_dim = input_z.get_shape().as_list()[-1]
    example_z = np.random.uniform(-1, 1, size=[n_images, z_dim])

    samples = sess.run(
        generator(input_z, out_channel_dim, False),
        feed_dict={input_z: example_z})

    images_grid = helper.images_square_grid(samples, image_mode)
    pyplot.imshow(images_grid, cmap=cmap)
    pyplot.show()

# %% [markdown]
# ### Train
# Implement `train` to build and train the GANs.  Use the following functions you implemented:
# - `model_inputs(image_width, image_height, image_channels, z_dim)`
# - `model_loss(input_real, input_z, out_channel_dim)`
# - `model_opt(d_loss, g_loss, learning_rate, beta1)`
#
# Use the `show_generator_output` to show `generator` output while you train. Running `show_generator_output` for every batch will drastically increase training time and increase the size of the notebook.  It's recommended to print the `generator` output every 100 batches.

# %%
def train(epoch_count, batch_size, z_dim, learning_rate, beta1, get_batches, data_shape, data_image_mode):
    """
    Train the GAN
    :param epoch_count: Number of epochs
    :param batch_size: Batch Size
    :param z_dim: Z dimension
    :param learning_rate: Learning Rate
    :param beta1: The exponential decay rate for the 1st moment in the optimizer
    :param get_batches: Function to get batches
    :param data_shape: Shape of the data
    :param data_image_mode: The image mode to use for images ("RGB" or "L")
    """
    # TODO: Build Model
    
    out_channel_dim = data_shape[3]
        
    image_width, image_height, image_channels = data_shape[1:]
    input_real, z_data, learning_rate_tensor = model_inputs(
        image_width, image_height, image_channels, z_dim)
    d_loss, g_loss = model_loss(input_real, z_data, out_channel_dim)
    d_train_opt, g_train_opt = model_opt(d_loss, g_loss, learning_rate_tensor, beta1)
    
    with tf.Session() as sess:
        sess.run(tf.global_variables_initializer())
        for epoch_i in range(epoch_count):
            num_batch = 0
            for batch_images in get_batches(batch_size):
                # TODO: Train Model
                num_batch += 1
                
                # scale batch image pixels to bring it to range [-1,1]
                batch_images = batch_images*2
                
                batch_z = np.random.uniform(-1, 1, size=(batch_size, z_dim))
                
                sess.run(g_train_opt, feed_dict={z_data: batch_z,
                                                learning_rate_tensor: learning_rate})
                sess.run(d_train_opt, feed_dict={input_real: batch_images,
                                                z_data: batch_z,
                                                learning_rate_tensor: learning_rate})
                
                if num_batch % 10 == 0:
                    # print the losses every x steps
                    g_loss_val = g_loss.eval(feed_dict={z_data: batch_z,
                                                learning_rate_tensor: learning_rate})
                    d_loss_val = d_loss.eval(feed_dict={input_real: batch_images,
                                                z_data: batch_z,
                                                learning_rate_tensor: learning_rate})

                    print("[epoch #{}, batch #{}]: discriminator_loss = {}, generator_loss = {}".format(
                    epoch_i+1, num_batch, d_loss_val, g_loss_val))
                    
                if num_batch % 200 == 0:
                    show_generator_output(sess, 25, z_data, out_channel_dim, data_image_mode)

# %% [markdown]
# ### MNIST
# Test your GANs architecture on MNIST.  After 2 epochs, the GANs should be able to generate images that look like handwritten digits.  Make sure the loss of the generator is lower than the loss of the discriminator or close to 0.

# %%
batch_size = 32
z_dim = 100
learning_rate = 0.0005
beta1 = 0.2


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
epochs = 2

mnist_dataset = helper.Dataset('mnist', glob(os.path.join(data_dir, 'mnist/*.jpg')))
with tf.Graph().as_default():
    train(epochs, batch_size, z_dim, learning_rate, beta1, mnist_dataset.get_batches,
          mnist_dataset.shape, mnist_dataset.image_mode)
# Out:
# [epoch #1, batch #10]: discriminator_loss = 0.6591112613677979, generator_loss = 15.348369598388672
# [epoch #1, batch #20]: discriminator_loss = 1.4892033338546753, generator_loss = 9.316224098205566
# [epoch #1, batch #30]: discriminator_loss = 0.7189033031463623, generator_loss = 17.289819717407227
# [epoch #1, batch #40]: discriminator_loss = 0.3948419392108917, generator_loss = 6.610822677612305
# [epoch #1, batch #50]: discriminator_loss = 0.34868958592414856, generator_loss = 6.449496269226074
# [epoch #1, batch #60]: discriminator_loss = 0.8267710208892822, generator_loss = 25.50728988647461
# [epoch #1, batch #70]: discriminator_loss = 2.658438205718994, generator_loss = 1.0556050539016724
# [epoch #1, batch #80]: discriminator_loss = 0.987104058265686, generator_loss = 1.148411750793457
# [epoch #1, batch #90]: discriminator_loss = 1.3039162158966064, generator_loss = 0.8266481161117554
# [epoch #1, batch #100]: discriminator_loss = 1.3471713066101074, generator_loss = 0.6785612106323242
# [epoch #1, batch #110]: discriminator_loss = 1.537793517112732, generator_loss = 0.5667620301246643
# [epoch #1, batch #120]: discriminator_loss = 1.2141211032867432, generator_loss = 0.7542955875396729
# [epoch #1, batch #130]: discriminator_loss = 1.4323835372924805, generator_loss = 0.5452688932418823
# [epoch #1, batch #140]: discriminator_loss = 1.3721450567245483, generator_loss = 0.7102378606796265
# [epoch #1, batch #150]: discriminator_loss = 1.3928474187850952, generator_loss = 0.6130416393280029
# [epoch #1, batch #160]: discriminator_loss = 1.0750378370285034, generator_loss = 0.8980265855789185
# [epoch #1, batch #170]: discriminator_loss = 1.2297229766845703, generator_loss = 2.182734489440918
# [epoch #1, batch #180]: discriminator_loss = 1.3878647089004517, generator_loss = 2.0450453758239746
# [epoch #1, batch #190]: discriminator_loss = 1.588788390159607, generator_loss = 2.6055147647857666
# [epoch #1, batch #200]: discriminator_loss = 1.2714260816574097, generator_loss = 1.9109662771224976
# [epoch #1, batch #210]: discriminator_loss = 1.5792328119277954, generator_loss = 2.5530624389648438
# [epoch #1, batch #220]: discriminator_loss = 1.499098300933838, generator_loss = 2.3318538665771484
# [epoch #1, batch #230]: discriminator_loss = 1.1148227453231812, generator_loss = 1.662013292312622
# [epoch #1, batch #240]: discriminator_loss = 1.3920655250549316, generator_loss = 2.060246706008911
# [epoch #1, batch #250]: discriminator_loss = 1.2020858526229858, generator_loss = 1.9136013984680176
# [epoch #1, batch #260]: discriminator_loss = 1.6664543151855469, generator_loss = 2.8704519271850586
# [epoch #1, batch #270]: discriminator_loss = 1.3869497776031494, generator_loss = 2.3765509128570557
# [epoch #1, batch #280]: discriminator_loss = 1.2654719352722168, generator_loss = 2.5312693119049072
# [epoch #1, batch #290]: discriminator_loss = 1.2016149759292603, generator_loss = 2.2336299419403076
# [epoch #1, batch #300]: discriminator_loss = 1.760190486907959, generator_loss = 3.5514438152313232
# [epoch #1, batch #310]: discriminator_loss = 1.3384602069854736, generator_loss = 0.5775885581970215
# [epoch #1, batch #320]: discriminator_loss = 1.4362499713897705, generator_loss = 0.5511053800582886
# [epoch #1, batch #330]: discriminator_loss = 1.349899411201477, generator_loss = 0.5180400013923645
# [epoch #1, batch #340]: discriminator_loss = 1.0890992879867554, generator_loss = 0.7529956102371216
# [epoch #1, batch #350]: discriminator_loss = 0.8822134137153625, generator_loss = 0.9686713814735413
# [epoch #1, batch #360]: discriminator_loss = 1.1488871574401855, generator_loss = 0.6941757798194885
# [epoch #1, batch #370]: discriminator_loss = 0.8774727582931519, generator_loss = 1.208642840385437
# [epoch #1, batch #380]: discriminator_loss = 1.0348806381225586, generator_loss = 0.826090395450592
# [epoch #1, batch #390]: discriminator_loss = 0.7119233012199402, generator_loss = 2.3876614570617676
# [epoch #1, batch #400]: discriminator_loss = 1.346889615058899, generator_loss = 3.1753056049346924
# [epoch #1, batch #410]: discriminator_loss = 0.774854302406311, generator_loss = 1.826136589050293
# [epoch #1, batch #420]: discriminator_loss = 1.2360682487487793, generator_loss = 3.497030735015869
# [epoch #1, batch #430]: discriminator_loss = 0.705187201499939, generator_loss = 2.303715705871582
# [epoch #1, batch #440]: discriminator_loss = 1.3868707418441772, generator_loss = 3.3195300102233887
# [epoch #1, batch #450]: discriminator_loss = 1.0154563188552856, generator_loss = 2.6616897583007812
# [epoch #1, batch #460]: discriminator_loss = 1.1050498485565186, generator_loss = 3.0986344814300537
# [epoch #1, batch #470]: discriminator_loss = 1.3519370555877686, generator_loss = 3.111304759979248
# [epoch #1, batch #480]: discriminator_loss = 1.0446548461914062, generator_loss = 2.2178096771240234
# [epoch #1, batch #490]: discriminator_loss = 1.7474554777145386, generator_loss = 5.201704978942871
# [epoch #1, batch #500]: discriminator_loss = 1.0156924724578857, generator_loss = 3.4243431091308594
# [epoch #1, batch #510]: discriminator_loss = 0.5642144680023193, generator_loss = 2.318918228149414
# [epoch #1, batch #520]: discriminator_loss = 0.541694700717926, generator_loss = 2.0396742820739746
# [epoch #1, batch #530]: discriminator_loss = 1.0506470203399658, generator_loss = 5.6739349365234375
# [epoch #1, batch #540]: discriminator_loss = 0.6803086400032043, generator_loss = 2.7355313301086426
# [epoch #1, batch #550]: discriminator_loss = 0.5804250836372375, generator_loss = 3.8205103874206543
# [epoch #1, batch #560]: discriminator_loss = 1.583441138267517, generator_loss = 4.596155166625977
# [epoch #1, batch #570]: discriminator_loss = 0.5564339756965637, generator_loss = 1.8823158740997314
# [epoch #1, batch #580]: discriminator_loss = 0.5105969905853271, generator_loss = 4.129658222198486
# [epoch #1, batch #590]: discriminator_loss = 1.465955138206482, generator_loss = 3.1920156478881836
# [epoch #1, batch #600]: discriminator_loss = 1.3516522645950317, generator_loss = 3.131913185119629
# [epoch #1, batch #610]: discriminator_loss = 0.9575981497764587, generator_loss = 2.069788932800293
# [epoch #1, batch #620]: discriminator_loss = 1.1596417427062988, generator_loss = 2.3326683044433594
# [epoch #1, batch #630]: discriminator_loss = 1.0803130865097046, generator_loss = 0.9426400661468506
# [epoch #1, batch #640]: discriminator_loss = 1.3903119564056396, generator_loss = 0.5355651378631592
# [epoch #1, batch #650]: discriminator_loss = 1.2992439270019531, generator_loss = 0.5955897569656372
# [epoch #1, batch #660]: discriminator_loss = 1.2770823240280151, generator_loss = 2.299549102783203
# [epoch #1, batch #670]: discriminator_loss = 1.5588798522949219, generator_loss = 2.8509607315063477
# [epoch #1, batch #680]: discriminator_loss = 1.2674942016601562, generator_loss = 2.603930950164795
# [epoch #1, batch #690]: discriminator_loss = 1.1005606651306152, generator_loss = 2.0651512145996094
# [epoch #1, batch #700]: discriminator_loss = 1.1411561965942383, generator_loss = 2.8111696243286133
# [epoch #1, batch #710]: discriminator_loss = 1.3806601762771606, generator_loss = 2.478060245513916
# [epoch #1, batch #720]: discriminator_loss = 1.0349795818328857, generator_loss = 1.7239387035369873
# [epoch #1, batch #730]: discriminator_loss = 1.1522544622421265, generator_loss = 1.7834548950195312
# [epoch #1, batch #740]: discriminator_loss = 0.977949321269989, generator_loss = 0.9712120294570923
# [epoch #1, batch #750]: discriminator_loss = 1.0915355682373047, generator_loss = 1.609323263168335
# [epoch #1, batch #760]: discriminator_loss = 1.2969436645507812, generator_loss = 2.6638455390930176
# [epoch #1, batch #770]: discriminator_loss = 1.002561092376709, generator_loss = 0.9222718477249146
# [epoch #1, batch #780]: discriminator_loss = 0.9869451522827148, generator_loss = 1.4005529880523682
# [epoch #1, batch #790]: discriminator_loss = 1.460928201675415, generator_loss = 0.4695667624473572
# [epoch #1, batch #800]: discriminator_loss = 1.1952145099639893, generator_loss = 1.8874914646148682
# [epoch #1, batch #810]: discriminator_loss = 1.4584236145019531, generator_loss = 2.6106112003326416
# [epoch #1, batch #820]: discriminator_loss = 1.5947883129119873, generator_loss = 2.440789222717285
# [epoch #1, batch #830]: discriminator_loss = 1.2069413661956787, generator_loss = 0.6910314559936523
# [epoch #1, batch #840]: discriminator_loss = 1.1851089000701904, generator_loss = 0.7851820588111877
# [epoch #1, batch #850]: discriminator_loss = 1.093583106994629, generator_loss = 1.1363773345947266
# [epoch #1, batch #860]: discriminator_loss = 1.3014779090881348, generator_loss = 0.6496063470840454
# [epoch #1, batch #870]: discriminator_loss = 1.0900075435638428, generator_loss = 0.8448653221130371
# [epoch #1, batch #880]: discriminator_loss = 1.2069088220596313, generator_loss = 1.7246211767196655
# [epoch #1, batch #890]: discriminator_loss = 1.0417470932006836, generator_loss = 1.5707467794418335
# [epoch #1, batch #900]: discriminator_loss = 1.4301166534423828, generator_loss = 0.49633660912513733
# [epoch #1, batch #910]: discriminator_loss = 1.359945297241211, generator_loss = 0.5494935512542725
# [epoch #1, batch #920]: discriminator_loss = 1.0990840196609497, generator_loss = 0.7729583978652954
# [epoch #1, batch #930]: discriminator_loss = 1.2689769268035889, generator_loss = 1.9404584169387817
# [epoch #1, batch #940]: discriminator_loss = 1.159304141998291, generator_loss = 1.8941130638122559
# [epoch #1, batch #950]: discriminator_loss = 1.0654003620147705, generator_loss = 1.8237988948822021
# [epoch #1, batch #960]: discriminator_loss = 1.121826410293579, generator_loss = 1.4159444570541382
# [epoch #1, batch #970]: discriminator_loss = 1.1239359378814697, generator_loss = 0.8551924228668213
# [epoch #1, batch #980]: discriminator_loss = 1.3240615129470825, generator_loss = 0.5460731387138367
# [epoch #1, batch #990]: discriminator_loss = 1.1484227180480957, generator_loss = 0.7381640672683716
# [epoch #1, batch #1000]: discriminator_loss = 1.1365721225738525, generator_loss = 0.7870864868164062
# [epoch #1, batch #1010]: discriminator_loss = 1.0540813207626343, generator_loss = 1.2302308082580566
# [epoch #1, batch #1020]: discriminator_loss = 1.3845094442367554, generator_loss = 2.271077871322632
# [epoch #1, batch #1030]: discriminator_loss = 1.2294939756393433, generator_loss = 2.0755834579467773
# [epoch #1, batch #1040]: discriminator_loss = 1.1880954504013062, generator_loss = 0.6527817845344543
# [epoch #1, batch #1050]: discriminator_loss = 1.2566463947296143, generator_loss = 0.634631335735321
# [epoch #1, batch #1060]: discriminator_loss = 0.9940187335014343, generator_loss = 1.5102486610412598
# [epoch #1, batch #1070]: discriminator_loss = 1.2198972702026367, generator_loss = 1.8713939189910889
# [epoch #1, batch #1080]: discriminator_loss = 1.0794651508331299, generator_loss = 1.8981126546859741
# [epoch #1, batch #1090]: discriminator_loss = 1.0344971418380737, generator_loss = 1.048855185508728
# [epoch #1, batch #1100]: discriminator_loss = 1.1752365827560425, generator_loss = 0.730512797832489
# [epoch #1, batch #1110]: discriminator_loss = 1.0851407051086426, generator_loss = 1.023457646369934
# [epoch #1, batch #1120]: discriminator_loss = 0.9829733967781067, generator_loss = 1.783913016319275
# [epoch #1, batch #1130]: discriminator_loss = 0.9569733142852783, generator_loss = 1.2793159484863281
# [epoch #1, batch #1140]: discriminator_loss = 1.121485948562622, generator_loss = 0.7943830490112305
# [epoch #1, batch #1150]: discriminator_loss = 1.3873907327651978, generator_loss = 0.5379148125648499
# [epoch #1, batch #1160]: discriminator_loss = 1.3543568849563599, generator_loss = 0.5311729907989502
# [epoch #1, batch #1170]: discriminator_loss = 1.1148006916046143, generator_loss = 1.064121961593628
# [epoch #1, batch #1180]: discriminator_loss = 1.0863897800445557, generator_loss = 1.29071044921875
# [epoch #1, batch #1190]: discriminator_loss = 1.2950247526168823, generator_loss = 0.5613073110580444
# [epoch #1, batch #1200]: discriminator_loss = 1.2546143531799316, generator_loss = 0.6314334273338318
# [epoch #1, batch #1210]: discriminator_loss = 1.2785496711730957, generator_loss = 0.5998923778533936
# [epoch #1, batch #1220]: discriminator_loss = 1.14262056350708, generator_loss = 0.7295130491256714
# [epoch #1, batch #1230]: discriminator_loss = 1.48037588596344, generator_loss = 0.48411279916763306
# [epoch #1, batch #1240]: discriminator_loss = 1.3087419271469116, generator_loss = 0.6181703805923462
# [epoch #1, batch #1250]: discriminator_loss = 1.2559418678283691, generator_loss = 0.6619724035263062
# [epoch #1, batch #1260]: discriminator_loss = 1.06167733669281, generator_loss = 1.062032699584961
# [epoch #1, batch #1270]: discriminator_loss = 1.1166012287139893, generator_loss = 1.6417933702468872
# [epoch #1, batch #1280]: discriminator_loss = 1.0272161960601807, generator_loss = 1.6281722784042358
# [epoch #1, batch #1290]: discriminator_loss = 1.236282229423523, generator_loss = 1.7269721031188965
# [epoch #1, batch #1300]: discriminator_loss = 1.1593043804168701, generator_loss = 2.5018203258514404
# [epoch #1, batch #1310]: discriminator_loss = 1.2894078493118286, generator_loss = 1.6501634120941162
# [epoch #1, batch #1320]: discriminator_loss = 1.2714605331420898, generator_loss = 2.303236246109009
# [epoch #1, batch #1330]: discriminator_loss = 1.0495102405548096, generator_loss = 1.776010513305664
# [epoch #1, batch #1340]: discriminator_loss = 1.153193473815918, generator_loss = 1.574691891670227
# [epoch #1, batch #1350]: discriminator_loss = 1.2020900249481201, generator_loss = 2.233898401260376
# [epoch #1, batch #1360]: discriminator_loss = 1.3369964361190796, generator_loss = 0.59857177734375
# [epoch #1, batch #1370]: discriminator_loss = 1.3159101009368896, generator_loss = 0.6499392986297607
# [epoch #1, batch #1380]: discriminator_loss = 1.3913556337356567, generator_loss = 0.5074787139892578
# [epoch #1, batch #1390]: discriminator_loss = 1.1832956075668335, generator_loss = 0.7061525583267212
# [epoch #1, batch #1400]: discriminator_loss = 1.1238188743591309, generator_loss = 0.8217817544937134
# [epoch #1, batch #1410]: discriminator_loss = 1.1620222330093384, generator_loss = 0.7917588353157043
# [epoch #1, batch #1420]: discriminator_loss = 1.015009880065918, generator_loss = 1.3677263259887695
# [epoch #1, batch #1430]: discriminator_loss = 1.1584563255310059, generator_loss = 1.556318998336792
# [epoch #1, batch #1440]: discriminator_loss = 1.0413968563079834, generator_loss = 1.4671599864959717
# [epoch #1, batch #1450]: discriminator_loss = 1.1822582483291626, generator_loss = 1.3861138820648193
# [epoch #1, batch #1460]: discriminator_loss = 1.1371549367904663, generator_loss = 1.2470569610595703
# [epoch #1, batch #1470]: discriminator_loss = 1.0656039714813232, generator_loss = 1.5390820503234863
# [epoch #1, batch #1480]: discriminator_loss = 1.1997501850128174, generator_loss = 1.5587260723114014
# [epoch #1, batch #1490]: discriminator_loss = 1.0278055667877197, generator_loss = 1.1484529972076416
# [epoch #1, batch #1500]: discriminator_loss = 1.2658770084381104, generator_loss = 1.7807650566101074
# [epoch #1, batch #1510]: discriminator_loss = 1.2275716066360474, generator_loss = 0.730660080909729
# [epoch #1, batch #1520]: discriminator_loss = 1.163984775543213, generator_loss = 0.7277883291244507
# [epoch #1, batch #1530]: discriminator_loss = 1.383791446685791, generator_loss = 0.5171009302139282
# [epoch #1, batch #1540]: discriminator_loss = 1.2209982872009277, generator_loss = 0.6728975772857666
# [epoch #1, batch #1550]: discriminator_loss = 1.0851733684539795, generator_loss = 0.9762885570526123
# [epoch #1, batch #1560]: discriminator_loss = 1.2723733186721802, generator_loss = 0.6046768426895142
# [epoch #1, batch #1570]: discriminator_loss = 1.2281399965286255, generator_loss = 0.652655303478241
# [epoch #1, batch #1580]: discriminator_loss = 1.088381290435791, generator_loss = 0.7889271378517151
# [epoch #1, batch #1590]: discriminator_loss = 0.9923655986785889, generator_loss = 1.3734238147735596
# [epoch #1, batch #1600]: discriminator_loss = 1.2968249320983887, generator_loss = 1.9199275970458984
# [epoch #1, batch #1610]: discriminator_loss = 1.1806515455245972, generator_loss = 1.5187621116638184
# [epoch #1, batch #1620]: discriminator_loss = 1.0532070398330688, generator_loss = 1.078867793083191
# [epoch #1, batch #1630]: discriminator_loss = 1.3114465475082397, generator_loss = 0.6195211410522461
# [epoch #1, batch #1640]: discriminator_loss = 1.225487470626831, generator_loss = 0.6532410979270935
# [epoch #1, batch #1650]: discriminator_loss = 1.3160085678100586, generator_loss = 0.5529825091362
# [epoch #1, batch #1660]: discriminator_loss = 1.1650854349136353, generator_loss = 0.7226080894470215
# [epoch #1, batch #1670]: discriminator_loss = 1.1919264793395996, generator_loss = 0.7641635537147522
# [epoch #1, batch #1680]: discriminator_loss = 1.2820239067077637, generator_loss = 0.6634582877159119
# [epoch #1, batch #1690]: discriminator_loss = 1.075599193572998, generator_loss = 0.81550133228302
# [epoch #1, batch #1700]: discriminator_loss = 1.1560490131378174, generator_loss = 0.728203535079956
# [epoch #1, batch #1710]: discriminator_loss = 0.9947147369384766, generator_loss = 1.06884765625
# [epoch #1, batch #1720]: discriminator_loss = 1.2446401119232178, generator_loss = 1.8219338655471802
# [epoch #1, batch #1730]: discriminator_loss = 1.242286205291748, generator_loss = 1.448901653289795
# [epoch #1, batch #1740]: discriminator_loss = 1.2374916076660156, generator_loss = 1.629345417022705
# [epoch #1, batch #1750]: discriminator_loss = 1.2187942266464233, generator_loss = 1.8861865997314453
# [epoch #1, batch #1760]: discriminator_loss = 1.0666711330413818, generator_loss = 0.9402169585227966
# [epoch #1, batch #1770]: discriminator_loss = 1.113508701324463, generator_loss = 1.6656721830368042
# [epoch #1, batch #1780]: discriminator_loss = 1.2779258489608765, generator_loss = 0.6432050466537476
# [epoch #1, batch #1790]: discriminator_loss = 1.26272714138031, generator_loss = 0.6421283483505249
# [epoch #1, batch #1800]: discriminator_loss = 1.14773428440094, generator_loss = 0.7427468299865723
# [epoch #1, batch #1810]: discriminator_loss = 1.1204923391342163, generator_loss = 0.9091216325759888
# [epoch #1, batch #1820]: discriminator_loss = 1.203312635421753, generator_loss = 1.7981021404266357
# [epoch #1, batch #1830]: discriminator_loss = 1.1436471939086914, generator_loss = 1.1586142778396606
# [epoch #1, batch #1840]: discriminator_loss = 1.1186760663986206, generator_loss = 1.5340046882629395
# [epoch #1, batch #1850]: discriminator_loss = 1.1326572895050049, generator_loss = 1.9272829294204712
# [epoch #1, batch #1860]: discriminator_loss = 1.2596144676208496, generator_loss = 2.243281841278076
# [epoch #1, batch #1870]: discriminator_loss = 1.123481035232544, generator_loss = 1.3385487794876099
# [epoch #2, batch #10]: discriminator_loss = 1.3519048690795898, generator_loss = 1.9367525577545166
# [epoch #2, batch #20]: discriminator_loss = 1.0672342777252197, generator_loss = 1.6622573137283325
# [epoch #2, batch #30]: discriminator_loss = 1.2230334281921387, generator_loss = 1.7325087785720825
# [epoch #2, batch #40]: discriminator_loss = 1.2140774726867676, generator_loss = 1.5531584024429321
# [epoch #2, batch #50]: discriminator_loss = 1.0899931192398071, generator_loss = 0.8726425170898438
# [epoch #2, batch #60]: discriminator_loss = 1.1433436870574951, generator_loss = 0.8207045793533325
# [epoch #2, batch #70]: discriminator_loss = 1.1102607250213623, generator_loss = 1.019080638885498
# [epoch #2, batch #80]: discriminator_loss = 1.08372962474823, generator_loss = 1.774032473564148
# [epoch #2, batch #90]: discriminator_loss = 1.3047125339508057, generator_loss = 2.130401611328125
# [epoch #2, batch #100]: discriminator_loss = 1.2021865844726562, generator_loss = 1.5979665517807007
# [epoch #2, batch #110]: discriminator_loss = 1.115147352218628, generator_loss = 1.3658963441848755
# [epoch #2, batch #120]: discriminator_loss = 1.0741056203842163, generator_loss = 1.6832258701324463
# [epoch #2, batch #130]: discriminator_loss = 1.1024868488311768, generator_loss = 0.9068893194198608
# [epoch #2, batch #140]: discriminator_loss = 1.2218376398086548, generator_loss = 0.6572670936584473
# [epoch #2, batch #150]: discriminator_loss = 1.176702857017517, generator_loss = 0.7240408062934875
# [epoch #2, batch #160]: discriminator_loss = 1.0639750957489014, generator_loss = 0.918384313583374
# [epoch #2, batch #170]: discriminator_loss = 1.1413332223892212, generator_loss = 0.7508993148803711
# [epoch #2, batch #180]: discriminator_loss = 1.106722116470337, generator_loss = 1.6075559854507446
# [epoch #2, batch #190]: discriminator_loss = 1.0669950246810913, generator_loss = 1.170793890953064
# [epoch #2, batch #200]: discriminator_loss = 1.2350068092346191, generator_loss = 0.6905182600021362
# [epoch #2, batch #210]: discriminator_loss = 1.0616378784179688, generator_loss = 1.2003268003463745
# [epoch #2, batch #220]: discriminator_loss = 1.4176678657531738, generator_loss = 0.48827749490737915
# [epoch #2, batch #230]: discriminator_loss = 1.2728431224822998, generator_loss = 0.6678582429885864
# [epoch #2, batch #240]: discriminator_loss = 1.3814823627471924, generator_loss = 2.0160369873046875
# [epoch #2, batch #250]: discriminator_loss = 1.1621016263961792, generator_loss = 1.198080062866211
# [epoch #2, batch #260]: discriminator_loss = 1.1485615968704224, generator_loss = 0.7568225860595703
# [epoch #2, batch #270]: discriminator_loss = 1.1252119541168213, generator_loss = 0.7937729954719543
# [epoch #2, batch #280]: discriminator_loss = 1.3275108337402344, generator_loss = 0.5875999927520752
# [epoch #2, batch #290]: discriminator_loss = 1.234910488128662, generator_loss = 0.7040724754333496
# [epoch #2, batch #300]: discriminator_loss = 1.1130011081695557, generator_loss = 0.8807793855667114
# [epoch #2, batch #310]: discriminator_loss = 1.087427020072937, generator_loss = 1.253564715385437
# [epoch #2, batch #320]: discriminator_loss = 1.250807523727417, generator_loss = 1.7788786888122559
# [epoch #2, batch #330]: discriminator_loss = 1.203357219696045, generator_loss = 0.7230000495910645
# [epoch #2, batch #340]: discriminator_loss = 1.279211163520813, generator_loss = 0.696243166923523
# [epoch #2, batch #350]: discriminator_loss = 1.3135021924972534, generator_loss = 0.5651805400848389
# [epoch #2, batch #360]: discriminator_loss = 1.258732795715332, generator_loss = 0.7229259610176086
# [epoch #2, batch #370]: discriminator_loss = 1.072243332862854, generator_loss = 0.9404306411743164
# [epoch #2, batch #380]: discriminator_loss = 1.1000534296035767, generator_loss = 0.8593029379844666
# [epoch #2, batch #390]: discriminator_loss = 0.9927306175231934, generator_loss = 1.1402602195739746
# [epoch #2, batch #400]: discriminator_loss = 1.0812653303146362, generator_loss = 1.4683998823165894
# [epoch #2, batch #410]: discriminator_loss = 1.4337211847305298, generator_loss = 2.2521462440490723
# [epoch #2, batch #420]: discriminator_loss = 1.0896090269088745, generator_loss = 1.389427661895752
# [epoch #2, batch #430]: discriminator_loss = 1.383509635925293, generator_loss = 1.7697219848632812
# [epoch #2, batch #440]: discriminator_loss = 1.1538984775543213, generator_loss = 1.3557147979736328
# [epoch #2, batch #450]: discriminator_loss = 1.2570592164993286, generator_loss = 1.755849838256836
# [epoch #2, batch #460]: discriminator_loss = 1.0800148248672485, generator_loss = 1.0073820352554321
# [epoch #2, batch #470]: discriminator_loss = 1.263831615447998, generator_loss = 0.689241886138916
# [epoch #2, batch #480]: discriminator_loss = 1.199051856994629, generator_loss = 0.7340127229690552
# [epoch #2, batch #490]: discriminator_loss = 1.3688807487487793, generator_loss = 2.1491494178771973
# [epoch #2, batch #500]: discriminator_loss = 1.4033281803131104, generator_loss = 2.1240620613098145
# [epoch #2, batch #510]: discriminator_loss = 0.9945217967033386, generator_loss = 1.258110523223877
# [epoch #2, batch #520]: discriminator_loss = 1.1152880191802979, generator_loss = 1.3851914405822754
# [epoch #2, batch #530]: discriminator_loss = 1.2658171653747559, generator_loss = 1.5962672233581543
# [epoch #2, batch #540]: discriminator_loss = 1.077628254890442, generator_loss = 1.2595679759979248
# [epoch #2, batch #550]: discriminator_loss = 1.2796809673309326, generator_loss = 1.8126749992370605
# [epoch #2, batch #560]: discriminator_loss = 1.0951496362686157, generator_loss = 0.9168297648429871
# [epoch #2, batch #570]: discriminator_loss = 1.1096017360687256, generator_loss = 1.318378210067749
# [epoch #2, batch #580]: discriminator_loss = 1.0963854789733887, generator_loss = 0.8128286004066467
# [epoch #2, batch #590]: discriminator_loss = 1.408119797706604, generator_loss = 0.47757500410079956
# [epoch #2, batch #600]: discriminator_loss = 0.9608852863311768, generator_loss = 1.1475529670715332
# [epoch #2, batch #610]: discriminator_loss = 1.1129435300827026, generator_loss = 0.8731094598770142
# [epoch #2, batch #620]: discriminator_loss = 1.1762723922729492, generator_loss = 1.369321346282959
# [epoch #2, batch #630]: discriminator_loss = 1.0671617984771729, generator_loss = 0.8939119577407837
# [epoch #2, batch #640]: discriminator_loss = 1.315134882926941, generator_loss = 0.5933823585510254
# [epoch #2, batch #650]: discriminator_loss = 1.0927674770355225, generator_loss = 0.8039647936820984
# [epoch #2, batch #660]: discriminator_loss = 1.1235814094543457, generator_loss = 1.1051990985870361
# [epoch #2, batch #670]: discriminator_loss = 1.1752060651779175, generator_loss = 1.4325475692749023
# [epoch #2, batch #680]: discriminator_loss = 1.0404064655303955, generator_loss = 0.9961602687835693
# [epoch #2, batch #690]: discriminator_loss = 1.2765780687332153, generator_loss = 0.5803526043891907
# [epoch #2, batch #700]: discriminator_loss = 1.2650585174560547, generator_loss = 0.6387820839881897
# [epoch #2, batch #710]: discriminator_loss = 1.1255967617034912, generator_loss = 0.8837050795555115
# [epoch #2, batch #720]: discriminator_loss = 1.0502740144729614, generator_loss = 1.1963527202606201
# [epoch #2, batch #730]: discriminator_loss = 1.0628107786178589, generator_loss = 0.8737794160842896
# [epoch #2, batch #740]: discriminator_loss = 1.1197514533996582, generator_loss = 1.1028988361358643
# [epoch #2, batch #750]: discriminator_loss = 1.100196123123169, generator_loss = 1.2439570426940918
# [epoch #2, batch #760]: discriminator_loss = 1.098299503326416, generator_loss = 1.7258509397506714
# [epoch #2, batch #770]: discriminator_loss = 1.1581284999847412, generator_loss = 1.844468355178833
# [epoch #2, batch #780]: discriminator_loss = 1.3200490474700928, generator_loss = 1.71845281124115
# [epoch #2, batch #790]: discriminator_loss = 1.1822168827056885, generator_loss = 1.5004448890686035
# [epoch #2, batch #800]: discriminator_loss = 1.304520845413208, generator_loss = 1.5379745960235596
# [epoch #2, batch #810]: discriminator_loss = 1.2820433378219604, generator_loss = 2.007612466812134
# [epoch #2, batch #820]: discriminator_loss = 1.2679798603057861, generator_loss = 1.9991095066070557
# [epoch #2, batch #830]: discriminator_loss = 1.0939582586288452, generator_loss = 0.9459795355796814
# [epoch #2, batch #840]: discriminator_loss = 1.179573655128479, generator_loss = 0.7884402275085449
# [epoch #2, batch #850]: discriminator_loss = 1.0499556064605713, generator_loss = 1.0993494987487793
# [epoch #2, batch #860]: discriminator_loss = 1.132940649986267, generator_loss = 1.3323323726654053
# [epoch #2, batch #870]: discriminator_loss = 1.1419198513031006, generator_loss = 1.3118056058883667
# [epoch #2, batch #880]: discriminator_loss = 1.131584882736206, generator_loss = 1.1781965494155884
# [epoch #2, batch #890]: discriminator_loss = 1.0373438596725464, generator_loss = 0.9787256121635437
# [epoch #2, batch #900]: discriminator_loss = 1.2602053880691528, generator_loss = 1.4578771591186523
# [epoch #2, batch #910]: discriminator_loss = 1.1415425539016724, generator_loss = 1.41727876663208
# [epoch #2, batch #920]: discriminator_loss = 1.1806379556655884, generator_loss = 0.7541725635528564
# [epoch #2, batch #930]: discriminator_loss = 1.199596881866455, generator_loss = 1.7976741790771484
# [epoch #2, batch #940]: discriminator_loss = 1.0915184020996094, generator_loss = 1.092057466506958
# [epoch #2, batch #950]: discriminator_loss = 1.3403757810592651, generator_loss = 2.024998664855957
# [epoch #2, batch #960]: discriminator_loss = 1.1877555847167969, generator_loss = 0.7222990989685059
# [epoch #2, batch #970]: discriminator_loss = 1.3111977577209473, generator_loss = 1.8668521642684937
# [epoch #2, batch #980]: discriminator_loss = 1.2616338729858398, generator_loss = 1.6556994915008545
# [epoch #2, batch #990]: discriminator_loss = 1.1151313781738281, generator_loss = 0.9121049642562866
# [epoch #2, batch #1000]: discriminator_loss = 1.106065034866333, generator_loss = 1.0459957122802734
# [epoch #2, batch #1010]: discriminator_loss = 1.1434590816497803, generator_loss = 1.528922200202942
# [epoch #2, batch #1020]: discriminator_loss = 1.2002630233764648, generator_loss = 0.783661961555481
# [epoch #2, batch #1030]: discriminator_loss = 1.2220087051391602, generator_loss = 1.7686200141906738
# [epoch #2, batch #1040]: discriminator_loss = 1.2868016958236694, generator_loss = 1.5488572120666504
# [epoch #2, batch #1050]: discriminator_loss = 1.1833394765853882, generator_loss = 0.6965743899345398
# [epoch #2, batch #1060]: discriminator_loss = 1.094204306602478, generator_loss = 1.0129292011260986
# [epoch #2, batch #1070]: discriminator_loss = 1.3588016033172607, generator_loss = 0.5514330267906189
# [epoch #2, batch #1080]: discriminator_loss = 1.100487232208252, generator_loss = 0.9884223937988281
# [epoch #2, batch #1090]: discriminator_loss = 1.1776373386383057, generator_loss = 0.7299542427062988
# [epoch #2, batch #1100]: discriminator_loss = 1.23722505569458, generator_loss = 0.736248791217804
# [epoch #2, batch #1110]: discriminator_loss = 1.2440567016601562, generator_loss = 0.7256289124488831
# [epoch #2, batch #1120]: discriminator_loss = 1.1803076267242432, generator_loss = 1.159510612487793
# [epoch #2, batch #1130]: discriminator_loss = 1.212554693222046, generator_loss = 0.7271624207496643
# [epoch #2, batch #1140]: discriminator_loss = 1.1759307384490967, generator_loss = 0.7425195574760437
# [epoch #2, batch #1150]: discriminator_loss = 1.13404381275177, generator_loss = 0.7539998292922974
# [epoch #2, batch #1160]: discriminator_loss = 1.1829051971435547, generator_loss = 0.7248861789703369
# [epoch #2, batch #1170]: discriminator_loss = 1.2922818660736084, generator_loss = 0.6274089813232422
# [epoch #2, batch #1180]: discriminator_loss = 1.211417317390442, generator_loss = 0.9004675149917603
# [epoch #2, batch #1190]: discriminator_loss = 1.144129991531372, generator_loss = 0.7738732695579529
# [epoch #2, batch #1200]: discriminator_loss = 1.2013897895812988, generator_loss = 0.7073222994804382
# [epoch #2, batch #1210]: discriminator_loss = 1.1966416835784912, generator_loss = 0.6521182060241699
# [epoch #2, batch #1220]: discriminator_loss = 1.1095558404922485, generator_loss = 0.9805024266242981
# [epoch #2, batch #1230]: discriminator_loss = 1.1063637733459473, generator_loss = 0.8416569828987122
# [epoch #2, batch #1240]: discriminator_loss = 1.2246896028518677, generator_loss = 0.8140416145324707
# [epoch #2, batch #1250]: discriminator_loss = 1.173853874206543, generator_loss = 1.1787996292114258
# [epoch #2, batch #1260]: discriminator_loss = 1.153195858001709, generator_loss = 1.2036709785461426
# [epoch #2, batch #1270]: discriminator_loss = 1.1886881589889526, generator_loss = 1.2581474781036377
# [epoch #2, batch #1280]: discriminator_loss = 1.0709114074707031, generator_loss = 1.1957499980926514
# [epoch #2, batch #1290]: discriminator_loss = 1.4014517068862915, generator_loss = 1.76167893409729
# [epoch #2, batch #1300]: discriminator_loss = 1.0816686153411865, generator_loss = 1.0022958517074585
# [epoch #2, batch #1310]: discriminator_loss = 1.214888334274292, generator_loss = 1.5584849119186401
# [epoch #2, batch #1320]: discriminator_loss = 1.2232557535171509, generator_loss = 1.755525827407837
# [epoch #2, batch #1330]: discriminator_loss = 1.1370410919189453, generator_loss = 1.243368148803711
# [epoch #2, batch #1340]: discriminator_loss = 1.2081007957458496, generator_loss = 1.239647388458252
# [epoch #2, batch #1350]: discriminator_loss = 1.1884181499481201, generator_loss = 1.6525639295578003
# [epoch #2, batch #1360]: discriminator_loss = 1.317463994026184, generator_loss = 1.3997178077697754
# [epoch #2, batch #1370]: discriminator_loss = 1.1966943740844727, generator_loss = 1.0527904033660889
# [epoch #2, batch #1380]: discriminator_loss = 1.3875657320022583, generator_loss = 1.6656213998794556
# [epoch #2, batch #1390]: discriminator_loss = 1.151092529296875, generator_loss = 0.9820574522018433
# [epoch #2, batch #1400]: discriminator_loss = 1.1643610000610352, generator_loss = 0.7922519445419312
# [epoch #2, batch #1410]: discriminator_loss = 1.1300020217895508, generator_loss = 1.3942843675613403
# [epoch #2, batch #1420]: discriminator_loss = 1.0732481479644775, generator_loss = 1.147522211074829
# [epoch #2, batch #1430]: discriminator_loss = 1.1497220993041992, generator_loss = 0.903419554233551
# [epoch #2, batch #1440]: discriminator_loss = 1.3534584045410156, generator_loss = 0.5609166622161865
# [epoch #2, batch #1450]: discriminator_loss = 1.2181578874588013, generator_loss = 0.8027291297912598
# [epoch #2, batch #1460]: discriminator_loss = 1.3591372966766357, generator_loss = 0.5634014010429382
# [epoch #2, batch #1470]: discriminator_loss = 1.1255857944488525, generator_loss = 0.8929949402809143
# [epoch #2, batch #1480]: discriminator_loss = 1.2129956483840942, generator_loss = 1.2609870433807373
# [epoch #2, batch #1490]: discriminator_loss = 1.2372727394104004, generator_loss = 1.371298909187317
# [epoch #2, batch #1500]: discriminator_loss = 1.2296135425567627, generator_loss = 0.6654106974601746
# [epoch #2, batch #1510]: discriminator_loss = 1.1747148036956787, generator_loss = 0.7832573056221008
# [epoch #2, batch #1520]: discriminator_loss = 1.3007941246032715, generator_loss = 0.6670938730239868
# [epoch #2, batch #1530]: discriminator_loss = 1.0829651355743408, generator_loss = 1.2241692543029785
# [epoch #2, batch #1540]: discriminator_loss = 1.2881534099578857, generator_loss = 0.6076472401618958
# [epoch #2, batch #1550]: discriminator_loss = 1.1940466165542603, generator_loss = 1.539950966835022
# [epoch #2, batch #1560]: discriminator_loss = 1.2149641513824463, generator_loss = 1.1655488014221191
# [epoch #2, batch #1570]: discriminator_loss = 1.1122937202453613, generator_loss = 0.9990469217300415
# [epoch #2, batch #1580]: discriminator_loss = 1.1175287961959839, generator_loss = 1.3504586219787598
# [epoch #2, batch #1590]: discriminator_loss = 1.2054625749588013, generator_loss = 1.4362000226974487
# [epoch #2, batch #1600]: discriminator_loss = 1.157130479812622, generator_loss = 1.2502076625823975
# [epoch #2, batch #1610]: discriminator_loss = 1.2451653480529785, generator_loss = 1.2988338470458984
# [epoch #2, batch #1620]: discriminator_loss = 1.1727688312530518, generator_loss = 0.7629010081291199
# [epoch #2, batch #1630]: discriminator_loss = 1.1702311038970947, generator_loss = 1.1137163639068604
# [epoch #2, batch #1640]: discriminator_loss = 1.1074068546295166, generator_loss = 0.9935517907142639
# [epoch #2, batch #1650]: discriminator_loss = 1.2742395401000977, generator_loss = 0.5938726663589478
# [epoch #2, batch #1660]: discriminator_loss = 1.2398338317871094, generator_loss = 0.7450307607650757
# [epoch #2, batch #1670]: discriminator_loss = 1.15510892868042, generator_loss = 1.0938687324523926
# [epoch #2, batch #1680]: discriminator_loss = 1.1823391914367676, generator_loss = 0.7504279017448425
# [epoch #2, batch #1690]: discriminator_loss = 1.2181096076965332, generator_loss = 1.443152666091919
# [epoch #2, batch #1700]: discriminator_loss = 1.1390825510025024, generator_loss = 1.1891582012176514
# [epoch #2, batch #1710]: discriminator_loss = 1.043555736541748, generator_loss = 1.2305994033813477
# [epoch #2, batch #1720]: discriminator_loss = 1.350635290145874, generator_loss = 1.6940594911575317
# [epoch #2, batch #1730]: discriminator_loss = 1.2197104692459106, generator_loss = 1.555100440979004
# [epoch #2, batch #1740]: discriminator_loss = 1.1695648431777954, generator_loss = 0.8418669700622559
# [epoch #2, batch #1750]: discriminator_loss = 1.1515741348266602, generator_loss = 0.8185112476348877
# [epoch #2, batch #1760]: discriminator_loss = 1.1423364877700806, generator_loss = 1.1208059787750244
# [epoch #2, batch #1770]: discriminator_loss = 1.33452308177948, generator_loss = 1.709342122077942
# [epoch #2, batch #1780]: discriminator_loss = 1.1994447708129883, generator_loss = 1.1744377613067627
# [epoch #2, batch #1790]: discriminator_loss = 1.1611050367355347, generator_loss = 1.0062878131866455
# [epoch #2, batch #1800]: discriminator_loss = 1.220248818397522, generator_loss = 0.7556425333023071
# [epoch #2, batch #1810]: discriminator_loss = 1.1499654054641724, generator_loss = 0.7584128379821777
# [epoch #2, batch #1820]: discriminator_loss = 1.1308526992797852, generator_loss = 0.7937243580818176
# [epoch #2, batch #1830]: discriminator_loss = 1.2989451885223389, generator_loss = 0.6695172786712646
# [epoch #2, batch #1840]: discriminator_loss = 1.3210670948028564, generator_loss = 0.620949387550354
# [epoch #2, batch #1850]: discriminator_loss = 1.1670643091201782, generator_loss = 0.9233216047286987
# [epoch #2, batch #1860]: discriminator_loss = 1.1577180624008179, generator_loss = 0.8470672369003296
# [epoch #2, batch #1870]: discriminator_loss = 1.211587905883789, generator_loss = 1.090907096862793

# %% [markdown]
# ### CelebA
# Run your GANs on CelebA.  It will take around 20 minutes on the average GPU to run one epoch.  You can run the whole epoch or stop when it starts to generate realistic faces.

# %%
batch_size = 32
z_dim = 100
learning_rate = 0.0005
beta1 = 0.2


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
epochs = 1

celeba_dataset = helper.Dataset('celeba', glob(os.path.join(data_dir, 'img_align_celeba/*.jpg')))
with tf.Graph().as_default():
    train(epochs, batch_size, z_dim, learning_rate, beta1, celeba_dataset.get_batches,
          celeba_dataset.shape, celeba_dataset.image_mode)
# Out:
# [epoch #1, batch #10]: discriminator_loss = 0.534697413444519, generator_loss = 6.172918319702148
# [epoch #1, batch #20]: discriminator_loss = 0.824674665927887, generator_loss = 6.912987232208252
# [epoch #1, batch #30]: discriminator_loss = 4.182966232299805, generator_loss = 19.06203842163086
# [epoch #1, batch #40]: discriminator_loss = 1.870039463043213, generator_loss = 4.362213134765625
# [epoch #1, batch #50]: discriminator_loss = 1.225574016571045, generator_loss = 3.427621603012085
# [epoch #1, batch #60]: discriminator_loss = 0.7617689371109009, generator_loss = 3.0963053703308105
# [epoch #1, batch #70]: discriminator_loss = 1.5617530345916748, generator_loss = 5.054475784301758
# [epoch #1, batch #80]: discriminator_loss = 2.1540026664733887, generator_loss = 6.376973628997803
# [epoch #1, batch #90]: discriminator_loss = 0.5201772451400757, generator_loss = 2.4952688217163086
# [epoch #1, batch #100]: discriminator_loss = 0.9961549043655396, generator_loss = 1.2240194082260132
# [epoch #1, batch #110]: discriminator_loss = 0.3793673515319824, generator_loss = 3.9310503005981445
# [epoch #1, batch #120]: discriminator_loss = 0.5113831162452698, generator_loss = 2.4825985431671143
# [epoch #1, batch #130]: discriminator_loss = 0.5730619430541992, generator_loss = 3.804490804672241
# [epoch #1, batch #140]: discriminator_loss = 1.5922386646270752, generator_loss = 3.5920615196228027
# [epoch #1, batch #150]: discriminator_loss = 1.11725914478302, generator_loss = 4.658805847167969
# [epoch #1, batch #160]: discriminator_loss = 0.4526563286781311, generator_loss = 3.877488613128662
# [epoch #1, batch #170]: discriminator_loss = 1.1581143140792847, generator_loss = 0.7846080660820007
# [epoch #1, batch #180]: discriminator_loss = 0.9582551121711731, generator_loss = 0.8975967168807983
# [epoch #1, batch #190]: discriminator_loss = 0.6143504977226257, generator_loss = 2.156707286834717
# [epoch #1, batch #200]: discriminator_loss = 0.5592561960220337, generator_loss = 2.0818991661071777
# [epoch #1, batch #210]: discriminator_loss = 0.5255194902420044, generator_loss = 2.1135218143463135
# [epoch #1, batch #220]: discriminator_loss = 0.8211978077888489, generator_loss = 2.476339340209961
# [epoch #1, batch #230]: discriminator_loss = 1.6996715068817139, generator_loss = 3.2203869819641113
# [epoch #1, batch #240]: discriminator_loss = 0.9675400257110596, generator_loss = 2.2373480796813965
# [epoch #1, batch #250]: discriminator_loss = 0.6896021366119385, generator_loss = 2.2485272884368896
# [epoch #1, batch #260]: discriminator_loss = 0.8156194686889648, generator_loss = 1.3971811532974243
# [epoch #1, batch #270]: discriminator_loss = 1.3580702543258667, generator_loss = 1.3587044477462769
# [epoch #1, batch #280]: discriminator_loss = 0.7112555503845215, generator_loss = 1.4278559684753418
# [epoch #1, batch #290]: discriminator_loss = 1.242404818534851, generator_loss = 0.7518473267555237
# [epoch #1, batch #300]: discriminator_loss = 0.7406271696090698, generator_loss = 2.297171115875244
# [epoch #1, batch #310]: discriminator_loss = 1.256304144859314, generator_loss = 1.2327837944030762
# [epoch #1, batch #320]: discriminator_loss = 1.471689224243164, generator_loss = 1.0485368967056274
# [epoch #1, batch #330]: discriminator_loss = 1.1862614154815674, generator_loss = 1.3981389999389648
# [epoch #1, batch #340]: discriminator_loss = 1.4322317838668823, generator_loss = 2.134253978729248
# [epoch #1, batch #350]: discriminator_loss = 0.873281717300415, generator_loss = 1.068329095840454
# [epoch #1, batch #360]: discriminator_loss = 0.7787986397743225, generator_loss = 1.243454098701477
# [epoch #1, batch #370]: discriminator_loss = 2.333523750305176, generator_loss = 3.7665483951568604
# [epoch #1, batch #380]: discriminator_loss = 0.591812014579773, generator_loss = 2.1034584045410156
# [epoch #1, batch #390]: discriminator_loss = 0.7248844504356384, generator_loss = 1.7458823919296265
# [epoch #1, batch #400]: discriminator_loss = 0.4376986026763916, generator_loss = 2.7158167362213135
# [epoch #1, batch #410]: discriminator_loss = 0.46416354179382324, generator_loss = 2.328258991241455
# [epoch #1, batch #420]: discriminator_loss = 1.2381340265274048, generator_loss = 0.6822388172149658
# [epoch #1, batch #430]: discriminator_loss = 0.6339945793151855, generator_loss = 1.6284000873565674
# [epoch #1, batch #440]: discriminator_loss = 0.47473084926605225, generator_loss = 2.1976466178894043
# [epoch #1, batch #450]: discriminator_loss = 0.3812620937824249, generator_loss = 3.5213074684143066
# [epoch #1, batch #460]: discriminator_loss = 0.435005247592926, generator_loss = 2.722355604171753
# [epoch #1, batch #470]: discriminator_loss = 0.42008721828460693, generator_loss = 3.069427251815796
# [epoch #1, batch #480]: discriminator_loss = 5.594814777374268, generator_loss = 7.185990333557129
# [epoch #1, batch #490]: discriminator_loss = 1.1698204278945923, generator_loss = 0.8558118343353271
# [epoch #1, batch #500]: discriminator_loss = 1.220076560974121, generator_loss = 1.004665732383728
# [epoch #1, batch #510]: discriminator_loss = 1.4209997653961182, generator_loss = 0.6176819801330566
# [epoch #1, batch #520]: discriminator_loss = 1.1244746446609497, generator_loss = 0.7092504501342773
# [epoch #1, batch #530]: discriminator_loss = 1.1186094284057617, generator_loss = 1.442276954650879
# [epoch #1, batch #540]: discriminator_loss = 1.3056434392929077, generator_loss = 2.2670187950134277
# [epoch #1, batch #550]: discriminator_loss = 1.094044804573059, generator_loss = 1.1418455839157104
# [epoch #1, batch #560]: discriminator_loss = 1.203234314918518, generator_loss = 0.9729134440422058
# [epoch #1, batch #570]: discriminator_loss = 1.057212471961975, generator_loss = 0.9312938451766968
# [epoch #1, batch #580]: discriminator_loss = 1.0721232891082764, generator_loss = 1.46940016746521
# [epoch #1, batch #590]: discriminator_loss = 1.3601821660995483, generator_loss = 1.6783753633499146
# [epoch #1, batch #600]: discriminator_loss = 1.3597357273101807, generator_loss = 2.694437265396118
# [epoch #1, batch #610]: discriminator_loss = 1.0265388488769531, generator_loss = 0.8928450345993042
# [epoch #1, batch #620]: discriminator_loss = 1.5087924003601074, generator_loss = 2.4543089866638184
# [epoch #1, batch #630]: discriminator_loss = 0.5947524309158325, generator_loss = 2.778775930404663
# [epoch #1, batch #640]: discriminator_loss = 0.4087873697280884, generator_loss = 2.8117763996124268
# [epoch #1, batch #650]: discriminator_loss = 0.7352800369262695, generator_loss = 1.4418283700942993
# [epoch #1, batch #660]: discriminator_loss = 0.510945737361908, generator_loss = 3.6252312660217285
# [epoch #1, batch #670]: discriminator_loss = 2.121471643447876, generator_loss = 4.803424835205078
# [epoch #1, batch #680]: discriminator_loss = 0.39626774191856384, generator_loss = 3.1582717895507812
# [epoch #1, batch #690]: discriminator_loss = 0.3862930238246918, generator_loss = 3.3166511058807373
# [epoch #1, batch #700]: discriminator_loss = 0.5171322822570801, generator_loss = 3.991112232208252
# [epoch #1, batch #710]: discriminator_loss = 1.0799579620361328, generator_loss = 1.5569586753845215
# [epoch #1, batch #720]: discriminator_loss = 1.259891152381897, generator_loss = 0.7136940956115723
# [epoch #1, batch #730]: discriminator_loss = 1.0898456573486328, generator_loss = 0.9383330345153809
# [epoch #1, batch #740]: discriminator_loss = 1.21021568775177, generator_loss = 0.602928102016449
# [epoch #1, batch #750]: discriminator_loss = 1.2101144790649414, generator_loss = 0.8120905756950378
# [epoch #1, batch #760]: discriminator_loss = 1.4659323692321777, generator_loss = 0.47538286447525024
# [epoch #1, batch #770]: discriminator_loss = 0.8941846489906311, generator_loss = 4.222348213195801
# [epoch #1, batch #780]: discriminator_loss = 1.0109487771987915, generator_loss = 0.9660646915435791
# [epoch #1, batch #790]: discriminator_loss = 1.0768239498138428, generator_loss = 0.9526673555374146
# [epoch #1, batch #800]: discriminator_loss = 0.8421180248260498, generator_loss = 1.5610692501068115
# [epoch #1, batch #810]: discriminator_loss = 1.1108886003494263, generator_loss = 0.8399926424026489
# [epoch #1, batch #820]: discriminator_loss = 1.2311111688613892, generator_loss = 2.2054805755615234
# [epoch #1, batch #830]: discriminator_loss = 1.028587818145752, generator_loss = 1.7137025594711304
# [epoch #1, batch #840]: discriminator_loss = 0.43228140473365784, generator_loss = 2.9846158027648926
# [epoch #1, batch #850]: discriminator_loss = 1.089900016784668, generator_loss = 1.3460673093795776
# [epoch #1, batch #860]: discriminator_loss = 0.8557285666465759, generator_loss = 1.0744117498397827
# [epoch #1, batch #870]: discriminator_loss = 1.006831169128418, generator_loss = 1.132950782775879
# [epoch #1, batch #880]: discriminator_loss = 0.8681804537773132, generator_loss = 1.1860904693603516
# [epoch #1, batch #890]: discriminator_loss = 1.0432102680206299, generator_loss = 1.1170079708099365
# [epoch #1, batch #900]: discriminator_loss = 0.7553285956382751, generator_loss = 1.2148888111114502
# [epoch #1, batch #910]: discriminator_loss = 0.5135541558265686, generator_loss = 3.1656198501586914
# [epoch #1, batch #920]: discriminator_loss = 0.4107120633125305, generator_loss = 2.7483699321746826
# [epoch #1, batch #930]: discriminator_loss = 1.5340873003005981, generator_loss = 0.4281831383705139
# [epoch #1, batch #940]: discriminator_loss = 1.119632363319397, generator_loss = 1.2126452922821045
# [epoch #1, batch #950]: discriminator_loss = 1.1881312131881714, generator_loss = 1.5553159713745117
# [epoch #1, batch #960]: discriminator_loss = 1.3615213632583618, generator_loss = 1.6497235298156738
# [epoch #1, batch #970]: discriminator_loss = 1.4472788572311401, generator_loss = 2.1517081260681152
# [epoch #1, batch #980]: discriminator_loss = 1.2624765634536743, generator_loss = 1.0491349697113037
# [epoch #1, batch #990]: discriminator_loss = 1.075321912765503, generator_loss = 0.7434154748916626
# [epoch #1, batch #1000]: discriminator_loss = 1.1067523956298828, generator_loss = 0.9902006387710571
# [epoch #1, batch #1010]: discriminator_loss = 1.368016004562378, generator_loss = 0.9767583608627319
# [epoch #1, batch #1020]: discriminator_loss = 1.2369271516799927, generator_loss = 1.3218348026275635
# [epoch #1, batch #1030]: discriminator_loss = 0.963972806930542, generator_loss = 1.6815451383590698
# [epoch #1, batch #1040]: discriminator_loss = 0.9256314635276794, generator_loss = 1.2007598876953125
# [epoch #1, batch #1050]: discriminator_loss = 1.352932333946228, generator_loss = 0.5408923029899597
# [epoch #1, batch #1060]: discriminator_loss = 0.9998885989189148, generator_loss = 1.6190474033355713
# [epoch #1, batch #1070]: discriminator_loss = 1.071663498878479, generator_loss = 0.920569121837616
# [epoch #1, batch #1080]: discriminator_loss = 1.0608752965927124, generator_loss = 1.335453748703003
# [epoch #1, batch #1090]: discriminator_loss = 1.135017991065979, generator_loss = 1.5555434226989746
# [epoch #1, batch #1100]: discriminator_loss = 1.1062242984771729, generator_loss = 0.9933489561080933
# [epoch #1, batch #1110]: discriminator_loss = 1.1545852422714233, generator_loss = 0.9312735199928284
# [epoch #1, batch #1120]: discriminator_loss = 1.1697473526000977, generator_loss = 0.7902097702026367
# [epoch #1, batch #1130]: discriminator_loss = 1.1591551303863525, generator_loss = 1.098738670349121
# [epoch #1, batch #1140]: discriminator_loss = 1.1462857723236084, generator_loss = 0.7858215570449829
# [epoch #1, batch #1150]: discriminator_loss = 1.089953899383545, generator_loss = 2.0067989826202393
# [epoch #1, batch #1160]: discriminator_loss = 1.1075012683868408, generator_loss = 1.3982371091842651
# [epoch #1, batch #1170]: discriminator_loss = 1.4408265352249146, generator_loss = 1.6985971927642822
# [epoch #1, batch #1180]: discriminator_loss = 0.761216938495636, generator_loss = 1.195688247680664
# [epoch #1, batch #1190]: discriminator_loss = 1.1832135915756226, generator_loss = 1.9793119430541992
# [epoch #1, batch #1200]: discriminator_loss = 1.1666514873504639, generator_loss = 1.1502017974853516
# [epoch #1, batch #1210]: discriminator_loss = 1.3061261177062988, generator_loss = 1.7850747108459473
# [epoch #1, batch #1220]: discriminator_loss = 1.0940788984298706, generator_loss = 0.788791835308075
# [epoch #1, batch #1230]: discriminator_loss = 1.48222815990448, generator_loss = 0.42153310775756836
# [epoch #1, batch #1240]: discriminator_loss = 1.2010135650634766, generator_loss = 1.1050840616226196
# [epoch #1, batch #1250]: discriminator_loss = 1.0612521171569824, generator_loss = 0.9452292919158936
# [epoch #1, batch #1260]: discriminator_loss = 0.99405837059021, generator_loss = 0.9885917901992798
# [epoch #1, batch #1270]: discriminator_loss = 1.098497748374939, generator_loss = 0.6985775232315063
# [epoch #1, batch #1280]: discriminator_loss = 0.9243307709693909, generator_loss = 1.2669410705566406
# [epoch #1, batch #1290]: discriminator_loss = 1.2207598686218262, generator_loss = 0.7531993389129639
# [epoch #1, batch #1300]: discriminator_loss = 1.056564450263977, generator_loss = 1.3790502548217773
# [epoch #1, batch #1310]: discriminator_loss = 1.2047934532165527, generator_loss = 1.0058257579803467
# [epoch #1, batch #1320]: discriminator_loss = 1.67865788936615, generator_loss = 2.5161824226379395
# [epoch #1, batch #1330]: discriminator_loss = 0.7718256711959839, generator_loss = 1.3045995235443115
# [epoch #1, batch #1340]: discriminator_loss = 1.023620367050171, generator_loss = 1.5954248905181885
# [epoch #1, batch #1350]: discriminator_loss = 1.1537425518035889, generator_loss = 1.0100897550582886
# [epoch #1, batch #1360]: discriminator_loss = 1.1793769598007202, generator_loss = 0.9481306076049805
# [epoch #1, batch #1370]: discriminator_loss = 0.9994000196456909, generator_loss = 1.1943472623825073
# [epoch #1, batch #1380]: discriminator_loss = 1.2951977252960205, generator_loss = 2.1095504760742188
# [epoch #1, batch #1390]: discriminator_loss = 1.1478554010391235, generator_loss = 2.081841468811035
# [epoch #1, batch #1400]: discriminator_loss = 1.0545233488082886, generator_loss = 1.7220985889434814
# [epoch #1, batch #1410]: discriminator_loss = 0.8897206783294678, generator_loss = 1.261068344116211
# [epoch #1, batch #1420]: discriminator_loss = 1.9475934505462646, generator_loss = 3.210141658782959
# [epoch #1, batch #1430]: discriminator_loss = 1.0871315002441406, generator_loss = 1.1108968257904053
# [epoch #1, batch #1440]: discriminator_loss = 1.1448919773101807, generator_loss = 1.0386335849761963
# [epoch #1, batch #1450]: discriminator_loss = 1.1921911239624023, generator_loss = 0.6356351971626282
# [epoch #1, batch #1460]: discriminator_loss = 1.0659222602844238, generator_loss = 0.8883751630783081
# [epoch #1, batch #1470]: discriminator_loss = 1.0152270793914795, generator_loss = 0.800064206123352
# [epoch #1, batch #1480]: discriminator_loss = 0.778540849685669, generator_loss = 1.8093836307525635
# [epoch #1, batch #1490]: discriminator_loss = 1.1700202226638794, generator_loss = 1.0221863985061646
# [epoch #1, batch #1500]: discriminator_loss = 1.2813161611557007, generator_loss = 0.5533608794212341
# [epoch #1, batch #1510]: discriminator_loss = 0.8730185627937317, generator_loss = 1.6903321743011475
# [epoch #1, batch #1520]: discriminator_loss = 1.0745307207107544, generator_loss = 0.9049933552742004
# [epoch #1, batch #1530]: discriminator_loss = 0.6952800750732422, generator_loss = 1.6086219549179077
# [epoch #1, batch #1540]: discriminator_loss = 2.0768229961395264, generator_loss = 2.6648454666137695
# [epoch #1, batch #1550]: discriminator_loss = 0.9412045478820801, generator_loss = 1.1366591453552246
# [epoch #1, batch #1560]: discriminator_loss = 1.0854483842849731, generator_loss = 1.555084228515625
# [epoch #1, batch #1570]: discriminator_loss = 0.7701622247695923, generator_loss = 1.302514910697937
# [epoch #1, batch #1580]: discriminator_loss = 1.1768338680267334, generator_loss = 0.8821158409118652
# [epoch #1, batch #1590]: discriminator_loss = 1.0953097343444824, generator_loss = 0.8607977628707886
# [epoch #1, batch #1600]: discriminator_loss = 1.034785509109497, generator_loss = 1.1261649131774902
# [epoch #1, batch #1610]: discriminator_loss = 1.1759097576141357, generator_loss = 1.1941698789596558
# [epoch #1, batch #1620]: discriminator_loss = 1.1684348583221436, generator_loss = 1.629082202911377
# [epoch #1, batch #1630]: discriminator_loss = 1.6192463636398315, generator_loss = 2.774765968322754
# [epoch #1, batch #1640]: discriminator_loss = 1.253145694732666, generator_loss = 0.6798628568649292
# [epoch #1, batch #1650]: discriminator_loss = 1.1914196014404297, generator_loss = 1.3252222537994385
# [epoch #1, batch #1660]: discriminator_loss = 1.9153715372085571, generator_loss = 2.798344850540161
# [epoch #1, batch #1670]: discriminator_loss = 1.1580153703689575, generator_loss = 1.3791245222091675
# [epoch #1, batch #1680]: discriminator_loss = 1.3033833503723145, generator_loss = 1.6133639812469482
# [epoch #1, batch #1690]: discriminator_loss = 1.0610133409500122, generator_loss = 1.3519569635391235
# [epoch #1, batch #1700]: discriminator_loss = 1.1292903423309326, generator_loss = 2.169447898864746
# [epoch #1, batch #1710]: discriminator_loss = 1.0293556451797485, generator_loss = 1.1697938442230225
# [epoch #1, batch #1720]: discriminator_loss = 1.0283052921295166, generator_loss = 0.7604593634605408
# [epoch #1, batch #1730]: discriminator_loss = 1.2568490505218506, generator_loss = 0.6500159502029419
# [epoch #1, batch #1740]: discriminator_loss = 0.9487228393554688, generator_loss = 0.9649860262870789
# [epoch #1, batch #1750]: discriminator_loss = 1.173701524734497, generator_loss = 0.7983099222183228
# [epoch #1, batch #1760]: discriminator_loss = 1.20701265335083, generator_loss = 2.910212516784668
# [epoch #1, batch #1770]: discriminator_loss = 1.1389505863189697, generator_loss = 1.0278172492980957
# [epoch #1, batch #1780]: discriminator_loss = 0.6082468628883362, generator_loss = 1.4668318033218384
# [epoch #1, batch #1790]: discriminator_loss = 1.1406068801879883, generator_loss = 1.2553013563156128
# [epoch #1, batch #1800]: discriminator_loss = 0.9050681591033936, generator_loss = 1.1917076110839844
# [epoch #1, batch #1810]: discriminator_loss = 1.2226970195770264, generator_loss = 0.7920352220535278
# [epoch #1, batch #1820]: discriminator_loss = 1.1312824487686157, generator_loss = 1.25199556350708
# [epoch #1, batch #1830]: discriminator_loss = 1.4019155502319336, generator_loss = 0.4748755395412445
# [epoch #1, batch #1840]: discriminator_loss = 1.0270075798034668, generator_loss = 0.8499765396118164
# [epoch #1, batch #1850]: discriminator_loss = 1.2705323696136475, generator_loss = 1.0579482316970825
# [epoch #1, batch #1860]: discriminator_loss = 1.2570875883102417, generator_loss = 0.8634645938873291
# [epoch #1, batch #1870]: discriminator_loss = 1.2421867847442627, generator_loss = 0.7233225703239441
# [epoch #1, batch #1880]: discriminator_loss = 1.2398953437805176, generator_loss = 0.9875397086143494
# [epoch #1, batch #1890]: discriminator_loss = 1.3726497888565063, generator_loss = 0.8846237659454346
# [epoch #1, batch #1900]: discriminator_loss = 1.3075734376907349, generator_loss = 0.8112058639526367
# [epoch #1, batch #1910]: discriminator_loss = 1.2288284301757812, generator_loss = 1.0895909070968628
# [epoch #1, batch #1920]: discriminator_loss = 1.3018105030059814, generator_loss = 0.6628204584121704
# [epoch #1, batch #1930]: discriminator_loss = 1.3279786109924316, generator_loss = 1.0742688179016113
# [epoch #1, batch #1940]: discriminator_loss = 1.3201942443847656, generator_loss = 0.6863192319869995
# [epoch #1, batch #1950]: discriminator_loss = 1.2844696044921875, generator_loss = 0.9427862167358398
# [epoch #1, batch #1960]: discriminator_loss = 1.3041192293167114, generator_loss = 0.9594203233718872
# [epoch #1, batch #1970]: discriminator_loss = 1.2809418439865112, generator_loss = 0.8580043315887451
# [epoch #1, batch #1980]: discriminator_loss = 1.2156367301940918, generator_loss = 0.974586546421051
# [epoch #1, batch #1990]: discriminator_loss = 1.2423181533813477, generator_loss = 0.911693811416626
# [epoch #1, batch #2000]: discriminator_loss = 1.3037071228027344, generator_loss = 1.1488158702850342
# [epoch #1, batch #2010]: discriminator_loss = 1.2759366035461426, generator_loss = 0.9601144790649414
# [epoch #1, batch #2020]: discriminator_loss = 1.3059484958648682, generator_loss = 0.9914582371711731
# [epoch #1, batch #2030]: discriminator_loss = 1.2067211866378784, generator_loss = 0.8899691700935364
# [epoch #1, batch #2040]: discriminator_loss = 1.298401117324829, generator_loss = 0.9947395324707031
# [epoch #1, batch #2050]: discriminator_loss = 1.298887014389038, generator_loss = 1.0851759910583496
# [epoch #1, batch #2060]: discriminator_loss = 1.2088356018066406, generator_loss = 1.013765573501587
# [epoch #1, batch #2070]: discriminator_loss = 1.2428333759307861, generator_loss = 1.2890870571136475
# [epoch #1, batch #2080]: discriminator_loss = 1.1821191310882568, generator_loss = 0.9123431444168091
# [epoch #1, batch #2090]: discriminator_loss = 1.1249417066574097, generator_loss = 1.229483962059021
# [epoch #1, batch #2100]: discriminator_loss = 1.2558555603027344, generator_loss = 1.3782756328582764
# [epoch #1, batch #2110]: discriminator_loss = 1.2904274463653564, generator_loss = 0.7488152980804443
# [epoch #1, batch #2120]: discriminator_loss = 1.2409272193908691, generator_loss = 0.7247729301452637
# [epoch #1, batch #2130]: discriminator_loss = 1.2043914794921875, generator_loss = 1.105204463005066
# [epoch #1, batch #2140]: discriminator_loss = 1.1061592102050781, generator_loss = 1.1174416542053223
# [epoch #1, batch #2150]: discriminator_loss = 1.3219118118286133, generator_loss = 2.5347719192504883
# [epoch #1, batch #2160]: discriminator_loss = 1.2020409107208252, generator_loss = 1.1797149181365967
# [epoch #1, batch #2170]: discriminator_loss = 1.1926414966583252, generator_loss = 0.6700149774551392
# [epoch #1, batch #2180]: discriminator_loss = 1.0512042045593262, generator_loss = 1.0056660175323486
# [epoch #1, batch #2190]: discriminator_loss = 1.2868611812591553, generator_loss = 0.9170162677764893
# [epoch #1, batch #2200]: discriminator_loss = 1.0815043449401855, generator_loss = 0.845217764377594
# [epoch #1, batch #2210]: discriminator_loss = 1.2036726474761963, generator_loss = 0.9222311973571777
# [epoch #1, batch #2220]: discriminator_loss = 1.1063940525054932, generator_loss = 0.8753951191902161
# [epoch #1, batch #2230]: discriminator_loss = 1.0464895963668823, generator_loss = 1.561340570449829
# [epoch #1, batch #2240]: discriminator_loss = 1.2782742977142334, generator_loss = 1.587425708770752
# [epoch #1, batch #2250]: discriminator_loss = 1.5320895910263062, generator_loss = 0.4276951849460602
# [epoch #1, batch #2260]: discriminator_loss = 1.1205319166183472, generator_loss = 1.2582809925079346
# [epoch #1, batch #2270]: discriminator_loss = 1.0550051927566528, generator_loss = 0.7579904794692993
# [epoch #1, batch #2280]: discriminator_loss = 0.6198011040687561, generator_loss = 2.355943202972412
# [epoch #1, batch #2290]: discriminator_loss = 1.259039282798767, generator_loss = 0.9773891568183899
# [epoch #1, batch #2300]: discriminator_loss = 1.2146637439727783, generator_loss = 1.0339140892028809
# [epoch #1, batch #2310]: discriminator_loss = 1.2731236219406128, generator_loss = 1.5254547595977783
# [epoch #1, batch #2320]: discriminator_loss = 1.0871306657791138, generator_loss = 1.0048083066940308
# [epoch #1, batch #2330]: discriminator_loss = 1.0629760026931763, generator_loss = 0.7226484417915344
# [epoch #1, batch #2340]: discriminator_loss = 1.210667371749878, generator_loss = 0.9172874689102173
# [epoch #1, batch #2350]: discriminator_loss = 1.178910255432129, generator_loss = 1.288435697555542
# [epoch #1, batch #2360]: discriminator_loss = 1.7737220525741577, generator_loss = 2.3562350273132324
# [epoch #1, batch #2370]: discriminator_loss = 1.043818473815918, generator_loss = 0.8085111379623413
# [epoch #1, batch #2380]: discriminator_loss = 1.1219663619995117, generator_loss = 0.727577805519104
# [epoch #1, batch #2390]: discriminator_loss = 1.2556285858154297, generator_loss = 1.2024645805358887
# [epoch #1, batch #2400]: discriminator_loss = 0.66135573387146, generator_loss = 1.8296715021133423
# [epoch #1, batch #2410]: discriminator_loss = 1.0401852130889893, generator_loss = 1.0293755531311035
# [epoch #1, batch #2420]: discriminator_loss = 0.8379274010658264, generator_loss = 1.3466360569000244
# [epoch #1, batch #2430]: discriminator_loss = 1.051833987236023, generator_loss = 2.1511471271514893
# [epoch #1, batch #2440]: discriminator_loss = 1.0763424634933472, generator_loss = 1.0485107898712158
# [epoch #1, batch #2450]: discriminator_loss = 1.8253461122512817, generator_loss = 0.3572882413864136
# [epoch #1, batch #2460]: discriminator_loss = 1.295459508895874, generator_loss = 0.9271419048309326
# [epoch #1, batch #2470]: discriminator_loss = 1.2676904201507568, generator_loss = 1.141509771347046
# [epoch #1, batch #2480]: discriminator_loss = 1.2539889812469482, generator_loss = 0.8145883679389954
# [epoch #1, batch #2490]: discriminator_loss = 1.3111402988433838, generator_loss = 0.9927513599395752
# [epoch #1, batch #2500]: discriminator_loss = 1.2936980724334717, generator_loss = 0.8498071432113647
# [epoch #1, batch #2510]: discriminator_loss = 1.2177150249481201, generator_loss = 0.9146790504455566
# [epoch #1, batch #2520]: discriminator_loss = 1.2288753986358643, generator_loss = 0.970262348651886
# [epoch #1, batch #2530]: discriminator_loss = 1.2827250957489014, generator_loss = 0.8727346062660217
# [epoch #1, batch #2540]: discriminator_loss = 1.3357888460159302, generator_loss = 0.9702996015548706
# [epoch #1, batch #2550]: discriminator_loss = 1.357123613357544, generator_loss = 0.8577898740768433
# [epoch #1, batch #2560]: discriminator_loss = 1.269428014755249, generator_loss = 1.0105044841766357
# [epoch #1, batch #2570]: discriminator_loss = 1.2929743528366089, generator_loss = 1.1447935104370117
# [epoch #1, batch #2580]: discriminator_loss = 1.3374786376953125, generator_loss = 1.0007245540618896
# [epoch #1, batch #2590]: discriminator_loss = 1.2888336181640625, generator_loss = 0.8998585939407349
# [epoch #1, batch #2600]: discriminator_loss = 1.298147201538086, generator_loss = 0.7437119483947754
# [epoch #1, batch #2610]: discriminator_loss = 1.3338994979858398, generator_loss = 0.8075268268585205
# [epoch #1, batch #2620]: discriminator_loss = 1.168453335762024, generator_loss = 0.9949016571044922
# [epoch #1, batch #2630]: discriminator_loss = 1.284392237663269, generator_loss = 0.7361359596252441
# [epoch #1, batch #2640]: discriminator_loss = 1.3581786155700684, generator_loss = 0.7294021248817444
# [epoch #1, batch #2650]: discriminator_loss = 1.295729160308838, generator_loss = 0.7678483128547668
# [epoch #1, batch #2660]: discriminator_loss = 1.229460597038269, generator_loss = 0.7975754737854004
# [epoch #1, batch #2670]: discriminator_loss = 1.3121795654296875, generator_loss = 0.7592837810516357
# [epoch #1, batch #2680]: discriminator_loss = 1.2696257829666138, generator_loss = 0.8055511713027954
# [epoch #1, batch #2690]: discriminator_loss = 1.2558313608169556, generator_loss = 0.7783406972885132
# [epoch #1, batch #2700]: discriminator_loss = 1.2603955268859863, generator_loss = 0.949637770652771
# [epoch #1, batch #2710]: discriminator_loss = 1.2892310619354248, generator_loss = 0.8622074127197266
# [epoch #1, batch #2720]: discriminator_loss = 1.2755467891693115, generator_loss = 0.7828909754753113
# [epoch #1, batch #2730]: discriminator_loss = 1.2457275390625, generator_loss = 1.0733766555786133
# [epoch #1, batch #2740]: discriminator_loss = 1.2777791023254395, generator_loss = 1.0124411582946777
# [epoch #1, batch #2750]: discriminator_loss = 1.325952410697937, generator_loss = 0.8414299488067627
# [epoch #1, batch #2760]: discriminator_loss = 1.2928531169891357, generator_loss = 1.0074857473373413
# [epoch #1, batch #2770]: discriminator_loss = 1.2599759101867676, generator_loss = 0.9800175428390503
# [epoch #1, batch #2780]: discriminator_loss = 1.3052427768707275, generator_loss = 0.7159719467163086
# [epoch #1, batch #2790]: discriminator_loss = 1.292038083076477, generator_loss = 1.017990231513977
# [epoch #1, batch #2800]: discriminator_loss = 1.309943675994873, generator_loss = 0.919994592666626
# [epoch #1, batch #2810]: discriminator_loss = 1.2630615234375, generator_loss = 0.983309805393219
# [epoch #1, batch #2820]: discriminator_loss = 1.2465730905532837, generator_loss = 0.8619229793548584
# [epoch #1, batch #2830]: discriminator_loss = 1.3602328300476074, generator_loss = 0.7701586484909058
# [epoch #1, batch #2840]: discriminator_loss = 1.2505371570587158, generator_loss = 0.8824607133865356
# [epoch #1, batch #2850]: discriminator_loss = 1.3297033309936523, generator_loss = 1.265546441078186
# [epoch #1, batch #2860]: discriminator_loss = 1.2030003070831299, generator_loss = 0.9179315567016602
# [epoch #1, batch #2870]: discriminator_loss = 1.2420647144317627, generator_loss = 0.868955135345459
# [epoch #1, batch #2880]: discriminator_loss = 1.2889125347137451, generator_loss = 0.9437459707260132
# [epoch #1, batch #2890]: discriminator_loss = 1.2199856042861938, generator_loss = 0.9791942238807678
# [epoch #1, batch #2900]: discriminator_loss = 1.2516260147094727, generator_loss = 0.8144413828849792
# [epoch #1, batch #2910]: discriminator_loss = 1.3332886695861816, generator_loss = 1.116620421409607
# [epoch #1, batch #2920]: discriminator_loss = 1.2445204257965088, generator_loss = 0.9259880781173706
# [epoch #1, batch #2930]: discriminator_loss = 1.2481977939605713, generator_loss = 1.0008271932601929
# [epoch #1, batch #2940]: discriminator_loss = 1.177879810333252, generator_loss = 0.8375711441040039
# [epoch #1, batch #2950]: discriminator_loss = 1.2567116022109985, generator_loss = 0.8048988580703735
# [epoch #1, batch #2960]: discriminator_loss = 1.24249267578125, generator_loss = 1.0554986000061035
# [epoch #1, batch #2970]: discriminator_loss = 1.2622861862182617, generator_loss = 0.7900298833847046
# [epoch #1, batch #2980]: discriminator_loss = 1.2134727239608765, generator_loss = 0.8862367868423462
# [epoch #1, batch #2990]: discriminator_loss = 1.2097394466400146, generator_loss = 0.9039770364761353
# [epoch #1, batch #3000]: discriminator_loss = 1.233025074005127, generator_loss = 0.8163032531738281
# [epoch #1, batch #3010]: discriminator_loss = 1.2591201066970825, generator_loss = 1.004158854484558
# [epoch #1, batch #3020]: discriminator_loss = 1.3100183010101318, generator_loss = 1.1056554317474365
# [epoch #1, batch #3030]: discriminator_loss = 1.1925855875015259, generator_loss = 0.9445210099220276
# [epoch #1, batch #3040]: discriminator_loss = 1.136606216430664, generator_loss = 1.289705514907837
# [epoch #1, batch #3050]: discriminator_loss = 1.1794663667678833, generator_loss = 0.9304572343826294
# [epoch #1, batch #3060]: discriminator_loss = 1.2614163160324097, generator_loss = 1.1150811910629272
# [epoch #1, batch #3070]: discriminator_loss = 1.0878897905349731, generator_loss = 1.179333209991455
# [epoch #1, batch #3080]: discriminator_loss = 1.1977646350860596, generator_loss = 1.2711396217346191
# [epoch #1, batch #3090]: discriminator_loss = 1.3489227294921875, generator_loss = 0.8866174221038818
# [epoch #1, batch #3100]: discriminator_loss = 1.3117177486419678, generator_loss = 1.7747329473495483
# [epoch #1, batch #3110]: discriminator_loss = 1.2431614398956299, generator_loss = 0.9414944648742676
# [epoch #1, batch #3120]: discriminator_loss = 1.2634823322296143, generator_loss = 0.993262767791748
# [epoch #1, batch #3130]: discriminator_loss = 1.1144647598266602, generator_loss = 0.9229336977005005
# [epoch #1, batch #3140]: discriminator_loss = 1.067388653755188, generator_loss = 1.3974297046661377
# [epoch #1, batch #3150]: discriminator_loss = 1.122794508934021, generator_loss = 0.8111560344696045
# [epoch #1, batch #3160]: discriminator_loss = 1.3858593702316284, generator_loss = 0.7677732706069946
# [epoch #1, batch #3170]: discriminator_loss = 1.1746081113815308, generator_loss = 1.0133490562438965
# [epoch #1, batch #3180]: discriminator_loss = 1.2660170793533325, generator_loss = 1.688786506652832
# [epoch #1, batch #3190]: discriminator_loss = 1.0075640678405762, generator_loss = 1.3515082597732544
# [epoch #1, batch #3200]: discriminator_loss = 0.9966163635253906, generator_loss = 1.0454715490341187
# [epoch #1, batch #3210]: discriminator_loss = 1.0664260387420654, generator_loss = 1.5718351602554321
# [epoch #1, batch #3220]: discriminator_loss = 1.0195693969726562, generator_loss = 1.5280895233154297
# [epoch #1, batch #3230]: discriminator_loss = 0.9468404054641724, generator_loss = 1.0111706256866455
# [epoch #1, batch #3240]: discriminator_loss = 0.9839901328086853, generator_loss = 1.2958616018295288
# [epoch #1, batch #3250]: discriminator_loss = 0.941702127456665, generator_loss = 1.2128561735153198
# [epoch #1, batch #3260]: discriminator_loss = 1.2752819061279297, generator_loss = 0.9729405641555786
# [epoch #1, batch #3270]: discriminator_loss = 1.3629961013793945, generator_loss = 0.5959433317184448
# [epoch #1, batch #3280]: discriminator_loss = 1.3679711818695068, generator_loss = 1.080970287322998
# [epoch #1, batch #3290]: discriminator_loss = 1.2751433849334717, generator_loss = 1.0093616247177124
# [epoch #1, batch #3300]: discriminator_loss = 1.2771472930908203, generator_loss = 1.16005539894104
# [epoch #1, batch #3310]: discriminator_loss = 1.303813099861145, generator_loss = 0.8124247789382935
# [epoch #1, batch #3320]: discriminator_loss = 1.2753878831863403, generator_loss = 0.877402663230896
# [epoch #1, batch #3330]: discriminator_loss = 1.2250256538391113, generator_loss = 0.7845544219017029
# [epoch #1, batch #3340]: discriminator_loss = 1.2384815216064453, generator_loss = 0.935816764831543
# [epoch #1, batch #3350]: discriminator_loss = 1.2861747741699219, generator_loss = 0.8550604581832886
# [epoch #1, batch #3360]: discriminator_loss = 1.272626519203186, generator_loss = 1.0068647861480713
# [epoch #1, batch #3370]: discriminator_loss = 1.3219943046569824, generator_loss = 0.9209243059158325
# [epoch #1, batch #3380]: discriminator_loss = 1.268957257270813, generator_loss = 0.8473666310310364
# [epoch #1, batch #3390]: discriminator_loss = 1.3348016738891602, generator_loss = 0.9300432801246643
# [epoch #1, batch #3400]: discriminator_loss = 1.1898763179779053, generator_loss = 1.0638742446899414
# [epoch #1, batch #3410]: discriminator_loss = 1.2805129289627075, generator_loss = 0.8219492435455322
# [epoch #1, batch #3420]: discriminator_loss = 1.2639729976654053, generator_loss = 0.8387097120285034
# [epoch #1, batch #3430]: discriminator_loss = 1.2703776359558105, generator_loss = 0.9365676045417786
# [epoch #1, batch #3440]: discriminator_loss = 1.1399356126785278, generator_loss = 0.9138641357421875
# [epoch #1, batch #3450]: discriminator_loss = 1.2160890102386475, generator_loss = 0.7607226371765137
# [epoch #1, batch #3460]: discriminator_loss = 1.2215228080749512, generator_loss = 1.2281467914581299
# [epoch #1, batch #3470]: discriminator_loss = 1.2462414503097534, generator_loss = 0.9959231615066528
# [epoch #1, batch #3480]: discriminator_loss = 1.2701075077056885, generator_loss = 1.4256179332733154
# [epoch #1, batch #3490]: discriminator_loss = 1.2077291011810303, generator_loss = 0.8279290795326233
# [epoch #1, batch #3500]: discriminator_loss = 1.1910327672958374, generator_loss = 1.078429102897644
# [epoch #1, batch #3510]: discriminator_loss = 1.1274607181549072, generator_loss = 0.9875894784927368
# [epoch #1, batch #3520]: discriminator_loss = 1.0457322597503662, generator_loss = 0.9189436435699463
# [epoch #1, batch #3530]: discriminator_loss = 1.6506489515304565, generator_loss = 1.965102195739746
# [epoch #1, batch #3540]: discriminator_loss = 1.1687676906585693, generator_loss = 1.0967841148376465
# [epoch #1, batch #3550]: discriminator_loss = 1.228762149810791, generator_loss = 0.8195986747741699
# [epoch #1, batch #3560]: discriminator_loss = 1.216315746307373, generator_loss = 0.8300471305847168
# [epoch #1, batch #3570]: discriminator_loss = 1.1855154037475586, generator_loss = 1.0535101890563965
# [epoch #1, batch #3580]: discriminator_loss = 1.1944985389709473, generator_loss = 0.9360939264297485
# [epoch #1, batch #3590]: discriminator_loss = 1.2358272075653076, generator_loss = 0.8964952230453491
# [epoch #1, batch #3600]: discriminator_loss = 1.2582223415374756, generator_loss = 0.6650078296661377
# [epoch #1, batch #3610]: discriminator_loss = 1.2519503831863403, generator_loss = 0.8139606714248657
# [epoch #1, batch #3620]: discriminator_loss = 1.296956181526184, generator_loss = 0.7255478501319885
# [epoch #1, batch #3630]: discriminator_loss = 1.237687349319458, generator_loss = 1.017463207244873
# [epoch #1, batch #3640]: discriminator_loss = 1.1976872682571411, generator_loss = 1.0904362201690674
# [epoch #1, batch #3650]: discriminator_loss = 1.216138243675232, generator_loss = 1.0232503414154053
# [epoch #1, batch #3660]: discriminator_loss = 1.0854344367980957, generator_loss = 0.8774968385696411
# [epoch #1, batch #3670]: discriminator_loss = 1.2355841398239136, generator_loss = 1.0038408041000366
# [epoch #1, batch #3680]: discriminator_loss = 1.1258031129837036, generator_loss = 1.1858341693878174
# [epoch #1, batch #3690]: discriminator_loss = 1.0444915294647217, generator_loss = 1.0745234489440918
# [epoch #1, batch #3700]: discriminator_loss = 1.0735571384429932, generator_loss = 1.2955234050750732
# [epoch #1, batch #3710]: discriminator_loss = 1.240002989768982, generator_loss = 0.8499786257743835
# [epoch #1, batch #3720]: discriminator_loss = 1.0024971961975098, generator_loss = 1.3628474473953247
# [epoch #1, batch #3730]: discriminator_loss = 1.2453054189682007, generator_loss = 0.8363914489746094
# [epoch #1, batch #3740]: discriminator_loss = 1.1474930047988892, generator_loss = 0.8274242877960205
# [epoch #1, batch #3750]: discriminator_loss = 1.0569862127304077, generator_loss = 1.115563154220581
# [epoch #1, batch #3760]: discriminator_loss = 1.2023205757141113, generator_loss = 0.8233643174171448
# [epoch #1, batch #3770]: discriminator_loss = 1.2857671976089478, generator_loss = 1.4861412048339844
# [epoch #1, batch #3780]: discriminator_loss = 1.3030102252960205, generator_loss = 0.8176502585411072
# [epoch #1, batch #3790]: discriminator_loss = 1.2921234369277954, generator_loss = 0.8215759992599487
# [epoch #1, batch #3800]: discriminator_loss = 1.1952049732208252, generator_loss = 0.9089417457580566
# [epoch #1, batch #3810]: discriminator_loss = 0.8471216559410095, generator_loss = 1.3108494281768799
# [epoch #1, batch #3820]: discriminator_loss = 1.2522121667861938, generator_loss = 0.7560054659843445
# [epoch #1, batch #3830]: discriminator_loss = 0.84273362159729, generator_loss = 1.2509814500808716
# [epoch #1, batch #3840]: discriminator_loss = 1.150124430656433, generator_loss = 1.004375696182251
# [epoch #1, batch #3850]: discriminator_loss = 1.186689853668213, generator_loss = 0.9239195585250854
# [epoch #1, batch #3860]: discriminator_loss = 1.239694595336914, generator_loss = 0.7239712476730347
# [epoch #1, batch #3870]: discriminator_loss = 1.084989309310913, generator_loss = 1.481705665588379
# [epoch #1, batch #3880]: discriminator_loss = 1.2174187898635864, generator_loss = 0.7314873933792114
# [epoch #1, batch #3890]: discriminator_loss = 1.038008213043213, generator_loss = 1.2885527610778809
# [epoch #1, batch #3900]: discriminator_loss = 1.196083664894104, generator_loss = 0.7735375165939331
# [epoch #1, batch #3910]: discriminator_loss = 1.2845401763916016, generator_loss = 0.9074280858039856
# [epoch #1, batch #3920]: discriminator_loss = 1.236223578453064, generator_loss = 0.9643787145614624
# [epoch #1, batch #3930]: discriminator_loss = 1.0862951278686523, generator_loss = 0.8479313254356384
# [epoch #1, batch #3940]: discriminator_loss = 1.190122365951538, generator_loss = 1.1999742984771729
# [epoch #1, batch #3950]: discriminator_loss = 1.258962631225586, generator_loss = 1.1553151607513428
# [epoch #1, batch #3960]: discriminator_loss = 0.8952191472053528, generator_loss = 1.2168470621109009
# [epoch #1, batch #3970]: discriminator_loss = 1.3911913633346558, generator_loss = 1.7266638278961182
# [epoch #1, batch #3980]: discriminator_loss = 1.2228724956512451, generator_loss = 0.8272525668144226
# [epoch #1, batch #3990]: discriminator_loss = 1.2064142227172852, generator_loss = 0.9889696836471558
# [epoch #1, batch #4000]: discriminator_loss = 1.1666706800460815, generator_loss = 1.2917661666870117
# [epoch #1, batch #4010]: discriminator_loss = 1.2017972469329834, generator_loss = 0.8452013731002808
# [epoch #1, batch #4020]: discriminator_loss = 1.1590609550476074, generator_loss = 0.8922230005264282
# [epoch #1, batch #4030]: discriminator_loss = 0.9618963003158569, generator_loss = 1.1214745044708252
# [epoch #1, batch #4040]: discriminator_loss = 1.1302518844604492, generator_loss = 1.109994888305664
# [epoch #1, batch #4050]: discriminator_loss = 1.2547963857650757, generator_loss = 0.928892195224762
# [epoch #1, batch #4060]: discriminator_loss = 1.2377938032150269, generator_loss = 0.8398915529251099
# [epoch #1, batch #4070]: discriminator_loss = 1.3037927150726318, generator_loss = 1.1374013423919678
# [epoch #1, batch #4080]: discriminator_loss = 1.0983837842941284, generator_loss = 1.3111555576324463
# [epoch #1, batch #4090]: discriminator_loss = 1.2924978733062744, generator_loss = 0.8335438966751099
# [epoch #1, batch #4100]: discriminator_loss = 1.183003306388855, generator_loss = 0.9433535933494568
# [epoch #1, batch #4110]: discriminator_loss = 1.1813724040985107, generator_loss = 0.933639407157898
# [epoch #1, batch #4120]: discriminator_loss = 1.2595313787460327, generator_loss = 0.9468320608139038
# [epoch #1, batch #4130]: discriminator_loss = 1.08076810836792, generator_loss = 1.066923975944519
# [epoch #1, batch #4140]: discriminator_loss = 1.158879280090332, generator_loss = 0.803855299949646
# [epoch #1, batch #4150]: discriminator_loss = 1.2943406105041504, generator_loss = 0.6494089365005493
# [epoch #1, batch #4160]: discriminator_loss = 1.0973331928253174, generator_loss = 1.6326940059661865
# [epoch #1, batch #4170]: discriminator_loss = 1.0835210084915161, generator_loss = 1.1617130041122437
# [epoch #1, batch #4180]: discriminator_loss = 1.1313362121582031, generator_loss = 0.9295912384986877
# [epoch #1, batch #4190]: discriminator_loss = 1.3038743734359741, generator_loss = 0.8547706604003906
# [epoch #1, batch #4200]: discriminator_loss = 1.2378177642822266, generator_loss = 1.0969940423965454
# [epoch #1, batch #4210]: discriminator_loss = 0.9977894425392151, generator_loss = 1.4465720653533936
# [epoch #1, batch #4220]: discriminator_loss = 1.1986162662506104, generator_loss = 0.9793468713760376
# [epoch #1, batch #4230]: discriminator_loss = 1.251976728439331, generator_loss = 1.0988681316375732
# [epoch #1, batch #4240]: discriminator_loss = 1.189129114151001, generator_loss = 0.9692420363426208
# [epoch #1, batch #4250]: discriminator_loss = 1.276376724243164, generator_loss = 1.0559335947036743
# [epoch #1, batch #4260]: discriminator_loss = 1.2608507871627808, generator_loss = 0.7901958227157593
# [epoch #1, batch #4270]: discriminator_loss = 1.2545726299285889, generator_loss = 0.8230782151222229
# [epoch #1, batch #4280]: discriminator_loss = 1.2411158084869385, generator_loss = 1.3001903295516968
# [epoch #1, batch #4290]: discriminator_loss = 1.2011080980300903, generator_loss = 0.9999979734420776
# [epoch #1, batch #4300]: discriminator_loss = 1.206876277923584, generator_loss = 0.8173691034317017
# [epoch #1, batch #4310]: discriminator_loss = 1.222154140472412, generator_loss = 0.9309735894203186
# [epoch #1, batch #4320]: discriminator_loss = 1.220010757446289, generator_loss = 0.9539014101028442
# [epoch #1, batch #4330]: discriminator_loss = 1.1920483112335205, generator_loss = 1.044617772102356
# [epoch #1, batch #4340]: discriminator_loss = 1.1799613237380981, generator_loss = 1.0598270893096924
# [epoch #1, batch #4350]: discriminator_loss = 1.2328026294708252, generator_loss = 0.8234512209892273
# [epoch #1, batch #4360]: discriminator_loss = 1.2104228734970093, generator_loss = 0.974160373210907
# [epoch #1, batch #4370]: discriminator_loss = 1.2761719226837158, generator_loss = 1.1687573194503784
# [epoch #1, batch #4380]: discriminator_loss = 1.2207565307617188, generator_loss = 0.924589991569519
# [epoch #1, batch #4390]: discriminator_loss = 1.2565269470214844, generator_loss = 0.8181158900260925
# [epoch #1, batch #4400]: discriminator_loss = 1.3068279027938843, generator_loss = 0.6163318157196045
# [epoch #1, batch #4410]: discriminator_loss = 1.24178147315979, generator_loss = 0.8690670132637024
# [epoch #1, batch #4420]: discriminator_loss = 1.3553369045257568, generator_loss = 0.7877120971679688
# [epoch #1, batch #4430]: discriminator_loss = 1.1973748207092285, generator_loss = 0.9355873465538025
# [epoch #1, batch #4440]: discriminator_loss = 1.3193235397338867, generator_loss = 1.0108489990234375
# [epoch #1, batch #4450]: discriminator_loss = 1.171424388885498, generator_loss = 0.8642665147781372
# [epoch #1, batch #4460]: discriminator_loss = 1.2028591632843018, generator_loss = 1.0787837505340576
# [epoch #1, batch #4470]: discriminator_loss = 1.224792718887329, generator_loss = 0.8136383295059204
# [epoch #1, batch #4480]: discriminator_loss = 1.189234733581543, generator_loss = 0.8931665420532227
# [epoch #1, batch #4490]: discriminator_loss = 1.2684900760650635, generator_loss = 0.9916558265686035
# [epoch #1, batch #4500]: discriminator_loss = 1.2169194221496582, generator_loss = 0.8965487480163574
# [epoch #1, batch #4510]: discriminator_loss = 1.2318851947784424, generator_loss = 0.8847438097000122
# [epoch #1, batch #4520]: discriminator_loss = 1.273555040359497, generator_loss = 0.9631158709526062
# [epoch #1, batch #4530]: discriminator_loss = 1.30220365524292, generator_loss = 0.956269383430481
# [epoch #1, batch #4540]: discriminator_loss = 1.126009225845337, generator_loss = 0.8969125747680664
# [epoch #1, batch #4550]: discriminator_loss = 1.1715458631515503, generator_loss = 1.0079214572906494
# [epoch #1, batch #4560]: discriminator_loss = 1.0858228206634521, generator_loss = 1.398095965385437
# [epoch #1, batch #4570]: discriminator_loss = 1.3022050857543945, generator_loss = 1.1015419960021973
# [epoch #1, batch #4580]: discriminator_loss = 1.285887598991394, generator_loss = 0.8233396410942078
# [epoch #1, batch #4590]: discriminator_loss = 1.2299516201019287, generator_loss = 0.9148365259170532
# [epoch #1, batch #4600]: discriminator_loss = 1.1563713550567627, generator_loss = 1.032210350036621
# [epoch #1, batch #4610]: discriminator_loss = 1.2219109535217285, generator_loss = 0.7666616439819336
# [epoch #1, batch #4620]: discriminator_loss = 1.1709275245666504, generator_loss = 0.8260552883148193
# [epoch #1, batch #4630]: discriminator_loss = 1.2184237241744995, generator_loss = 0.8876669406890869
# [epoch #1, batch #4640]: discriminator_loss = 0.995184063911438, generator_loss = 1.3327012062072754
# [epoch #1, batch #4650]: discriminator_loss = 1.2686235904693604, generator_loss = 1.1593616008758545
# [epoch #1, batch #4660]: discriminator_loss = 1.2831088304519653, generator_loss = 0.8761368989944458
# [epoch #1, batch #4670]: discriminator_loss = 1.250215768814087, generator_loss = 0.8355584740638733
# [epoch #1, batch #4680]: discriminator_loss = 1.0309181213378906, generator_loss = 1.2699015140533447
# [epoch #1, batch #4690]: discriminator_loss = 0.9343764781951904, generator_loss = 1.0751057863235474
# [epoch #1, batch #4700]: discriminator_loss = 1.2201170921325684, generator_loss = 0.9313477873802185
# [epoch #1, batch #4710]: discriminator_loss = 1.25935697555542, generator_loss = 0.9127833247184753
# [epoch #1, batch #4720]: discriminator_loss = 1.2917189598083496, generator_loss = 0.7926207780838013
# [epoch #1, batch #4730]: discriminator_loss = 1.2476900815963745, generator_loss = 1.0463759899139404
# ...
# [epoch #1, batch #4770]: discriminator_loss = 1.2706985473632812, generator_loss = 0.9783793687820435
# [epoch #1, batch #4780]: discriminator_loss = 1.2959269285202026, generator_loss = 0.8399444818496704
# [epoch #1, batch #4790]: discriminator_loss = 1.3238669633865356, generator_loss = 1.033719778060913
# [epoch #1, batch #4800]: discriminator_loss = 1.2832164764404297, generator_loss = 0.9088369011878967
# [epoch #1, batch #4810]: discriminator_loss = 1.2614190578460693, generator_loss = 0.7496888637542725
# [epoch #1, batch #4820]: discriminator_loss = 1.3084421157836914, generator_loss = 1.2346311807632446
# [epoch #1, batch #4830]: discriminator_loss = 1.318298578262329, generator_loss = 0.8752939105033875
# [epoch #1, batch #4840]: discriminator_loss = 1.290931224822998, generator_loss = 0.7182347178459167
# [epoch #1, batch #4850]: discriminator_loss = 1.3366241455078125, generator_loss = 0.8601454496383667
# [epoch #1, batch #4860]: discriminator_loss = 1.2679550647735596, generator_loss = 0.8667105436325073
# [epoch #1, batch #4870]: discriminator_loss = 1.2643954753875732, generator_loss = 0.8238719701766968
# [epoch #1, batch #4880]: discriminator_loss = 1.3026835918426514, generator_loss = 0.9156932234764099
# [epoch #1, batch #4890]: discriminator_loss = 1.3336323499679565, generator_loss = 0.81671142578125
# [epoch #1, batch #4900]: discriminator_loss = 1.251875638961792, generator_loss = 0.8558256030082703
# [epoch #1, batch #4910]: discriminator_loss = 1.2794599533081055, generator_loss = 1.0995447635650635
# [epoch #1, batch #4920]: discriminator_loss = 1.2871558666229248, generator_loss = 0.8561210632324219
# [epoch #1, batch #4930]: discriminator_loss = 1.2701815366744995, generator_loss = 0.7740796804428101
# [epoch #1, batch #4940]: discriminator_loss = 1.3453762531280518, generator_loss = 0.804767370223999
# [epoch #1, batch #4950]: discriminator_loss = 1.3362793922424316, generator_loss = 0.917190432548523
# [epoch #1, batch #4960]: discriminator_loss = 1.3296993970870972, generator_loss = 0.8671284317970276
# [epoch #1, batch #4970]: discriminator_loss = 1.3247463703155518, generator_loss = 0.8254692554473877
# [epoch #1, batch #4980]: discriminator_loss = 1.312412977218628, generator_loss = 0.8712788820266724
# [epoch #1, batch #4990]: discriminator_loss = 1.3490644693374634, generator_loss = 0.8763179779052734
# [epoch #1, batch #5000]: discriminator_loss = 1.327380657196045, generator_loss = 0.7986661791801453
# [epoch #1, batch #5010]: discriminator_loss = 1.3268113136291504, generator_loss = 0.9026424288749695
# [epoch #1, batch #5020]: discriminator_loss = 1.3058415651321411, generator_loss = 0.8735345602035522
# [epoch #1, batch #5030]: discriminator_loss = 1.26227605342865, generator_loss = 1.034591794013977
# [epoch #1, batch #5040]: discriminator_loss = 1.2874727249145508, generator_loss = 0.8216396570205688
# [epoch #1, batch #5050]: discriminator_loss = 1.313753604888916, generator_loss = 0.8206844925880432
# [epoch #1, batch #5060]: discriminator_loss = 1.3167155981063843, generator_loss = 0.9086132645606995
# [epoch #1, batch #5070]: discriminator_loss = 1.332187533378601, generator_loss = 0.9265668392181396
# [epoch #1, batch #5080]: discriminator_loss = 1.295733094215393, generator_loss = 0.9116061925888062
# [epoch #1, batch #5090]: discriminator_loss = 1.2416489124298096, generator_loss = 0.8368003964424133
# [epoch #1, batch #5100]: discriminator_loss = 1.3167223930358887, generator_loss = 0.9091430902481079
# [epoch #1, batch #5110]: discriminator_loss = 1.294682264328003, generator_loss = 0.8707289695739746
# [epoch #1, batch #5120]: discriminator_loss = 1.2996199131011963, generator_loss = 0.9811058640480042
# [epoch #1, batch #5130]: discriminator_loss = 1.2753115892410278, generator_loss = 0.8877793550491333
# [epoch #1, batch #5140]: discriminator_loss = 1.2798047065734863, generator_loss = 0.9000868201255798
# [epoch #1, batch #5150]: discriminator_loss = 1.35383939743042, generator_loss = 0.9519078135490417
# [epoch #1, batch #5160]: discriminator_loss = 1.3288499116897583, generator_loss = 1.0014032125473022
# [epoch #1, batch #5170]: discriminator_loss = 1.2651859521865845, generator_loss = 0.8489071130752563
# [epoch #1, batch #5180]: discriminator_loss = 1.2587058544158936, generator_loss = 0.8878661394119263
# [epoch #1, batch #5190]: discriminator_loss = 1.2775964736938477, generator_loss = 0.8943511247634888
# [epoch #1, batch #5200]: discriminator_loss = 1.2820258140563965, generator_loss = 0.9201000928878784
# [epoch #1, batch #5210]: discriminator_loss = 1.3268046379089355, generator_loss = 0.8530463576316833
# [epoch #1, batch #5220]: discriminator_loss = 1.2943823337554932, generator_loss = 0.8652442693710327
# [epoch #1, batch #5230]: discriminator_loss = 1.310899019241333, generator_loss = 0.9985619783401489
# [epoch #1, batch #5240]: discriminator_loss = 1.313841700553894, generator_loss = 0.7746696472167969
# [epoch #1, batch #5250]: discriminator_loss = 1.2985191345214844, generator_loss = 1.0129408836364746
# [epoch #1, batch #5260]: discriminator_loss = 1.3272701501846313, generator_loss = 0.8700137138366699
# [epoch #1, batch #5270]: discriminator_loss = 1.2655950784683228, generator_loss = 0.9061930179595947
# [epoch #1, batch #5280]: discriminator_loss = 1.3309690952301025, generator_loss = 0.8477739095687866
# [epoch #1, batch #5290]: discriminator_loss = 1.308546781539917, generator_loss = 0.9035478234291077
# [epoch #1, batch #5300]: discriminator_loss = 1.286766529083252, generator_loss = 0.8430342078208923
# [epoch #1, batch #5310]: discriminator_loss = 1.2965672016143799, generator_loss = 0.8149518966674805
# [epoch #1, batch #5320]: discriminator_loss = 1.2909741401672363, generator_loss = 0.8476727604866028
# [epoch #1, batch #5330]: discriminator_loss = 1.32206130027771, generator_loss = 0.9264382123947144
# [epoch #1, batch #5340]: discriminator_loss = 1.3084995746612549, generator_loss = 0.917921245098114
# [epoch #1, batch #5350]: discriminator_loss = 1.289319396018982, generator_loss = 0.8477373123168945
# [epoch #1, batch #5360]: discriminator_loss = 1.260072946548462, generator_loss = 0.8883014917373657
# [epoch #1, batch #5370]: discriminator_loss = 1.3288229703903198, generator_loss = 0.8161493539810181
# [epoch #1, batch #5380]: discriminator_loss = 1.2917687892913818, generator_loss = 0.90655118227005
# [epoch #1, batch #5390]: discriminator_loss = 1.2717090845108032, generator_loss = 1.0140540599822998
# [epoch #1, batch #5400]: discriminator_loss = 1.3539469242095947, generator_loss = 0.7708698511123657
# [epoch #1, batch #5410]: discriminator_loss = 1.27020263671875, generator_loss = 0.8808473348617554
# [epoch #1, batch #5420]: discriminator_loss = 1.2450876235961914, generator_loss = 0.9402871131896973
# [epoch #1, batch #5430]: discriminator_loss = 1.29817795753479, generator_loss = 0.8607648611068726
# [epoch #1, batch #5440]: discriminator_loss = 1.3330334424972534, generator_loss = 0.7638685703277588
# [epoch #1, batch #5450]: discriminator_loss = 1.271962285041809, generator_loss = 0.9380840063095093
# [epoch #1, batch #5460]: discriminator_loss = 1.3111371994018555, generator_loss = 0.8969727754592896
# [epoch #1, batch #5470]: discriminator_loss = 1.3100745677947998, generator_loss = 1.032862901687622
# [epoch #1, batch #5480]: discriminator_loss = 1.2693367004394531, generator_loss = 0.9954276084899902
# [epoch #1, batch #5490]: discriminator_loss = 1.2821522951126099, generator_loss = 0.900584876537323
# [epoch #1, batch #5500]: discriminator_loss = 1.3204951286315918, generator_loss = 0.8429282903671265
# [epoch #1, batch #5510]: discriminator_loss = 1.3228131532669067, generator_loss = 0.8360294103622437
# [epoch #1, batch #5520]: discriminator_loss = 1.2963109016418457, generator_loss = 0.8995625972747803
# [epoch #1, batch #5530]: discriminator_loss = 1.2971290349960327, generator_loss = 0.8877737522125244
# [epoch #1, batch #5540]: discriminator_loss = 1.2636306285858154, generator_loss = 0.9870643615722656
# [epoch #1, batch #5550]: discriminator_loss = 1.303166151046753, generator_loss = 0.8763330578804016
# [epoch #1, batch #5560]: discriminator_loss = 1.2950299978256226, generator_loss = 0.9586399793624878
# [epoch #1, batch #5570]: discriminator_loss = 1.3174359798431396, generator_loss = 0.7714753150939941
# [epoch #1, batch #5580]: discriminator_loss = 1.2765965461730957, generator_loss = 0.8006216287612915
# [epoch #1, batch #5590]: discriminator_loss = 1.271941065788269, generator_loss = 0.892313539981842
# [epoch #1, batch #5600]: discriminator_loss = 1.314032793045044, generator_loss = 0.8100818395614624
# [epoch #1, batch #5610]: discriminator_loss = 1.200911521911621, generator_loss = 0.9668365716934204
# [epoch #1, batch #5620]: discriminator_loss = 1.30130934715271, generator_loss = 0.7974401712417603
# [epoch #1, batch #5630]: discriminator_loss = 1.260853886604309, generator_loss = 0.9157124757766724
# [epoch #1, batch #5640]: discriminator_loss = 1.2881723642349243, generator_loss = 1.2368419170379639
# [epoch #1, batch #5650]: discriminator_loss = 1.27638840675354, generator_loss = 1.0216450691223145
# [epoch #1, batch #5660]: discriminator_loss = 1.277779459953308, generator_loss = 0.888965368270874
# [epoch #1, batch #5670]: discriminator_loss = 1.2506310939788818, generator_loss = 0.8046510219573975
# [epoch #1, batch #5680]: discriminator_loss = 1.257481575012207, generator_loss = 1.0630638599395752
# [epoch #1, batch #5690]: discriminator_loss = 1.2310967445373535, generator_loss = 1.1570968627929688
# [epoch #1, batch #5700]: discriminator_loss = 1.3099822998046875, generator_loss = 0.8420583009719849
# [epoch #1, batch #5710]: discriminator_loss = 1.3612747192382812, generator_loss = 0.9632198810577393
# [epoch #1, batch #5720]: discriminator_loss = 1.3598852157592773, generator_loss = 0.8683340549468994
# [epoch #1, batch #5730]: discriminator_loss = 1.2931187152862549, generator_loss = 0.8454891443252563
# [epoch #1, batch #5740]: discriminator_loss = 1.3192366361618042, generator_loss = 0.9216000437736511
# [epoch #1, batch #5750]: discriminator_loss = 1.3315472602844238, generator_loss = 0.8586177229881287
# [epoch #1, batch #5760]: discriminator_loss = 1.3445615768432617, generator_loss = 0.8857091665267944
# [epoch #1, batch #5770]: discriminator_loss = 1.2860112190246582, generator_loss = 0.9543522596359253
# [epoch #1, batch #5780]: discriminator_loss = 1.3277575969696045, generator_loss = 0.8488319516181946
# [epoch #1, batch #5790]: discriminator_loss = 1.2942407131195068, generator_loss = 0.7395355701446533
# [epoch #1, batch #5800]: discriminator_loss = 1.3488085269927979, generator_loss = 1.001678228378296
# [epoch #1, batch #5810]: discriminator_loss = 1.2881879806518555, generator_loss = 0.8417322635650635
# [epoch #1, batch #5820]: discriminator_loss = 1.30511474609375, generator_loss = 0.8394500017166138
# [epoch #1, batch #5830]: discriminator_loss = 1.3297650814056396, generator_loss = 0.8512011766433716
# [epoch #1, batch #5840]: discriminator_loss = 1.3160386085510254, generator_loss = 0.8789417743682861
# [epoch #1, batch #5850]: discriminator_loss = 1.3462162017822266, generator_loss = 0.7735192775726318
# [epoch #1, batch #5860]: discriminator_loss = 1.2991712093353271, generator_loss = 0.9177712202072144
# [epoch #1, batch #5870]: discriminator_loss = 1.3138315677642822, generator_loss = 0.9183770418167114
# [epoch #1, batch #5880]: discriminator_loss = 1.2891864776611328, generator_loss = 0.8494058847427368
# [epoch #1, batch #5890]: discriminator_loss = 1.316519021987915, generator_loss = 0.8343122005462646
# [epoch #1, batch #5900]: discriminator_loss = 1.3264789581298828, generator_loss = 0.9392704963684082
# [epoch #1, batch #5910]: discriminator_loss = 1.3393242359161377, generator_loss = 0.8071668744087219
# [epoch #1, batch #5920]: discriminator_loss = 1.3183742761611938, generator_loss = 0.8422585725784302
# [epoch #1, batch #5930]: discriminator_loss = 1.319461703300476, generator_loss = 0.7942364811897278
# [epoch #1, batch #5940]: discriminator_loss = 1.323562741279602, generator_loss = 0.862420916557312
# [epoch #1, batch #5950]: discriminator_loss = 1.327405333518982, generator_loss = 0.8031493425369263
# [epoch #1, batch #5960]: discriminator_loss = 1.3442168235778809, generator_loss = 0.7999321818351746
# [epoch #1, batch #5970]: discriminator_loss = 1.2841441631317139, generator_loss = 0.8174582719802856
# [epoch #1, batch #5980]: discriminator_loss = 1.2900433540344238, generator_loss = 0.7921567559242249
# [epoch #1, batch #5990]: discriminator_loss = 1.3107995986938477, generator_loss = 0.8617597818374634
# [epoch #1, batch #6000]: discriminator_loss = 1.314550518989563, generator_loss = 0.8292399644851685
# [epoch #1, batch #6010]: discriminator_loss = 1.3373987674713135, generator_loss = 0.9600255489349365
# [epoch #1, batch #6020]: discriminator_loss = 1.331876516342163, generator_loss = 0.8350483179092407
# [epoch #1, batch #6030]: discriminator_loss = 1.3388158082962036, generator_loss = 0.7694358825683594
# [epoch #1, batch #6040]: discriminator_loss = 1.3399467468261719, generator_loss = 0.854107141494751
# [epoch #1, batch #6050]: discriminator_loss = 1.3048641681671143, generator_loss = 0.7765294313430786
# [epoch #1, batch #6060]: discriminator_loss = 1.368791103363037, generator_loss = 0.8403897881507874
# [epoch #1, batch #6070]: discriminator_loss = 1.334801197052002, generator_loss = 0.848342776298523
# [epoch #1, batch #6080]: discriminator_loss = 1.3330368995666504, generator_loss = 0.7782183289527893
# [epoch #1, batch #6090]: discriminator_loss = 1.3140898942947388, generator_loss = 0.7438859939575195
# [epoch #1, batch #6100]: discriminator_loss = 1.3198204040527344, generator_loss = 0.7576885223388672
# [epoch #1, batch #6110]: discriminator_loss = 1.3066911697387695, generator_loss = 0.7629420757293701
# [epoch #1, batch #6120]: discriminator_loss = 1.3209712505340576, generator_loss = 0.7626213431358337
# [epoch #1, batch #6130]: discriminator_loss = 1.3295743465423584, generator_loss = 0.878157913684845
# [epoch #1, batch #6140]: discriminator_loss = 1.3287901878356934, generator_loss = 0.7904964685440063
# [epoch #1, batch #6150]: discriminator_loss = 1.3426969051361084, generator_loss = 0.7862471342086792
# [epoch #1, batch #6160]: discriminator_loss = 1.3395893573760986, generator_loss = 0.8366413116455078
# [epoch #1, batch #6170]: discriminator_loss = 1.3361191749572754, generator_loss = 0.8021847605705261
# [epoch #1, batch #6180]: discriminator_loss = 1.3254895210266113, generator_loss = 0.8666454553604126
# [epoch #1, batch #6190]: discriminator_loss = 1.3258068561553955, generator_loss = 0.8448866605758667
# [epoch #1, batch #6200]: discriminator_loss = 1.288786768913269, generator_loss = 0.8216058015823364
# [epoch #1, batch #6210]: discriminator_loss = 1.281021237373352, generator_loss = 0.8793774247169495
# [epoch #1, batch #6220]: discriminator_loss = 1.3017446994781494, generator_loss = 0.9754687547683716
# [epoch #1, batch #6230]: discriminator_loss = 1.3132377862930298, generator_loss = 0.8714815378189087
# [epoch #1, batch #6240]: discriminator_loss = 1.2838528156280518, generator_loss = 0.8563151359558105
# [epoch #1, batch #6250]: discriminator_loss = 1.335533618927002, generator_loss = 0.8732578754425049
# [epoch #1, batch #6260]: discriminator_loss = 1.3030316829681396, generator_loss = 0.8613296747207642
# [epoch #1, batch #6270]: discriminator_loss = 1.31559419631958, generator_loss = 0.8173914551734924
# [epoch #1, batch #6280]: discriminator_loss = 1.2938597202301025, generator_loss = 0.8703595399856567
# [epoch #1, batch #6290]: discriminator_loss = 1.3482078313827515, generator_loss = 0.8186764121055603
# [epoch #1, batch #6300]: discriminator_loss = 1.326015830039978, generator_loss = 0.7647574543952942
# [epoch #1, batch #6310]: discriminator_loss = 1.3188378810882568, generator_loss = 0.7531095147132874
# [epoch #1, batch #6320]: discriminator_loss = 1.2961840629577637, generator_loss = 0.9336192607879639
# [epoch #1, batch #6330]: discriminator_loss = 1.3098747730255127, generator_loss = 0.8847315311431885

# %% [markdown]
# ### Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook. Save the notebook file as "dlnd_face_generation.ipynb" and save it as a HTML file under "File" -> "Download as". Include the "helper.py" and "problem_unittests.py" files in your submission.
